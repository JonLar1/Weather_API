# %% [markdown]
# # Task
#
# - Get current weather
# - Get a forecast
# - Get some astronomical data
# - Get anything else you want (challenge)
# - Build a summary for the city, save that into a dictionary

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import requests

# %% [markdown]
# ## API Info

# %%
api_key = "<REDACTED_API_KEY>"
baseurl = "http://api.weatherapi.com/v1/"
city = "Louisville"

# %% [markdown]
# ### Check API access and JSON data

# %%
# Current Weather

weather_url = f"{baseurl}current.json?key={api_key}&q={city}"
weather_response = requests.get(weather_url)
weather_response.status_code
# Out:
# 200

# %%
weather_response.json()
# Out:
# {'location': {'name': 'Louisville',
#   'region': 'Kentucky',
#   'country': 'United States of America',
#   'lat': 38.2542,
#   'lon': -85.7594,
#   'tz_id': 'America/Kentucky/Louisville',
#   'localtime_epoch': 1767132435,
#   'localtime': '2025-12-30 17:07'},
#  'current': {'last_updated_epoch': 1767132000,
#   'last_updated': '2025-12-30 17:00',
#   'temp_c': -1.1,
#   'temp_f': 30.0,
#   'is_day': 1,
#   'condition': {'text': 'Overcast',
#    'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#    'code': 1009},
#   'wind_mph': 9.4,
#   'wind_kph': 15.1,
#   'wind_degree': 273,
#   'wind_dir': 'W',
#   'pressure_mb': 1022.0,
#   'pressure_in': 30.19,
#   'precip_mm': 0.0,
#   'precip_in': 0.0,
#   'humidity': 43,
#   'cloud': 100,
#   'feelslike_c': -5.8,
#   'feelslike_f': 21.6,
#   'windchill_c': -4.5,
#   'windchill_f': 23.9,
#   'heatindex_c': -0.3,
#   'heatindex_f': 31.5,
#   'dewpoint_c': -8.4,
#   'dewpoint_f': 16.9,
#   'vis_km': 16.0,
#   'vis_miles': 9.0,
#   'uv': 0.0,
#   'gust_mph': 11.9,
#   'gust_kph': 19.1,
#   'short_rad': 278.58,
#   'diff_rad': 93.19,
#   'dni': 0.0,
#   'gti': 89.17}}

# %%
# Forecast

forecast_url = f"{baseurl}forecast.json?key={api_key}&q={city}&days=3"
forecast_response = requests.get(forecast_url)

forecast_response.status_code
# Out:
# 200

# %%
forecast_response.json()
# Out:
# {'location': {'name': 'Louisville',
#   'region': 'Kentucky',
#   'country': 'United States of America',
#   'lat': 38.2542,
#   'lon': -85.7594,
#   'tz_id': 'America/Kentucky/Louisville',
#   'localtime_epoch': 1767132470,
#   'localtime': '2025-12-30 17:07'},
#  'current': {'last_updated_epoch': 1767132000,
#   'last_updated': '2025-12-30 17:00',
#   'temp_c': -1.1,
#   'temp_f': 30.0,
#   'is_day': 1,
#   'condition': {'text': 'Overcast',
#    'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#    'code': 1009},
#   'wind_mph': 9.4,
#   'wind_kph': 15.1,
#   'wind_degree': 273,
#   'wind_dir': 'W',
#   'pressure_mb': 1022.0,
#   'pressure_in': 30.19,
#   'precip_mm': 0.0,
#   'precip_in': 0.0,
#   'humidity': 43,
#   'cloud': 100,
#   'feelslike_c': -5.8,
#   'feelslike_f': 21.6,
#   'windchill_c': -4.5,
#   'windchill_f': 23.9,
#   'heatindex_c': -0.3,
#   'heatindex_f': 31.5,
#   'dewpoint_c': -8.4,
#   'dewpoint_f': 16.9,
#   'vis_km': 16.0,
#   'vis_miles': 9.0,
#   'uv': 0.0,
#   'gust_mph': 11.9,
#   'gust_kph': 19.1,
#   'short_rad': 278.58,
#   'diff_rad': 93.19,
#   'dni': 0.0,
#   'gti': 89.17},
#  'forecast': {'forecastday': [{'date': '2025-12-30',
#     'date_epoch': 1767052800,
#     'day': {'maxtemp_c': 0.3,
#      'maxtemp_f': 32.5,
#      'mintemp_c': -7.5,
#      'mintemp_f': 18.5,
#      'avgtemp_c': -4.0,
#      'avgtemp_f': 24.8,
#      'maxwind_mph': 11.2,
#      'maxwind_kph': 18.0,
#      'totalprecip_mm': 0.05,
#      'totalprecip_in': 0.0,
#      'totalsnow_cm': 0.0,
#      'avgvis_km': 10.0,
#      'avgvis_miles': 6.0,
#      'avghumidity': 61,
#      'daily_will_it_rain': 0,
#      'daily_chance_of_rain': 0,
#      'daily_will_it_snow': 0,
#      'daily_chance_of_snow': 6,
#      'condition': {'text': 'Partly Cloudy ',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#       'code': 1003},
#      'uv': 0.3},
#     'astro': {'sunrise': '08:00 AM',
#      'sunset': '05:32 PM',
#      'moonrise': '01:52 PM',
#      'moonset': '03:47 AM',
#      'moon_phase': 'Waxing Gibbous',
#      'moon_illumination': 74,
#      'is_moon_up': 1,
#      'is_sun_up': 0},
#     'hour': [{'time_epoch': 1767070800,
#       'time': '2025-12-30 00:00',
#       'temp_c': -3.5,
#       'temp_f': 25.8,
#       'is_day': 0,
#       'condition': {'text': 'Light freezing rain',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/311.png',
#        'code': 1198},
#       'wind_mph': 11.2,
#       'wind_kph': 18.0,
#       'wind_degree': 299,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1025.0,
#       'pressure_in': 30.27,
#       'precip_mm': 0.04,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 72,
#       'cloud': 100,
#       'feelslike_c': -9.4,
#       'feelslike_f': 15.0,
#       'windchill_c': -9.4,
#       'windchill_f': 15.0,
#       'heatindex_c': -3.5,
#       'heatindex_f': 25.8,
#       'dewpoint_c': -6.9,
#       'dewpoint_f': 19.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 61,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 13.7,
#       'gust_kph': 22.0,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1767074400,
#       'time': '2025-12-30 01:00',
#       'temp_c': -4.2,
#       'temp_f': 24.4,
#       'is_day': 0,
#       'condition': {'text': 'Light freezing rain',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/311.png',
#        'code': 1198},
#       'wind_mph': 10.7,
#       'wind_kph': 17.3,
#       'wind_degree': 296,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1025.0,
#       'pressure_in': 30.28,
#       'precip_mm': 0.01,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 67,
#       'cloud': 100,
#       'feelslike_c': -10.1,
#       'feelslike_f': 13.9,
#       'windchill_c': -10.1,
#       'windchill_f': 13.9,
#       'heatindex_c': -4.2,
#       'heatindex_f': 24.4,
#       'dewpoint_c': -9.8,
#       'dewpoint_f': 14.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 1,
#       'chance_of_snow': 80,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 13.0,
#       'gust_kph': 21.0,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1767078000,
#       'time': '2025-12-30 02:00',
#       'temp_c': -4.7,
#       'temp_f': 23.5,
#       'is_day': 0,
#       'condition': {'text': 'Clear ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 10.5,
#       'wind_kph': 16.9,
#       'wind_degree': 297,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1026.0,
#       'pressure_in': 30.29,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 67,
#       'cloud': 22,
#       'feelslike_c': -10.5,
#       'feelslike_f': 13.0,
#       'windchill_c': -10.5,
#       'windchill_f': 13.0,
#       'heatindex_c': -4.7,
#       'heatindex_f': 23.5,
#       'dewpoint_c': -10.2,
#       'dewpoint_f': 13.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 12.7,
#       'gust_kph': 20.4,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1767081600,
#       'time': '2025-12-30 03:00',
#       'temp_c': -5.1,
#       'temp_f': 22.9,
#       'is_day': 0,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#        'code': 1009},
#       'wind_mph': 10.1,
#       'wind_kph': 16.2,
#       'wind_degree': 301,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1026.0,
#       'pressure_in': 30.3,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 68,
#       'cloud': 100,
#       'feelslike_c': -11.0,
#       'feelslike_f': 12.2,
#       'windchill_c': -11.0,
#       'windchill_f': 12.2,
#       'heatindex_c': -5.1,
#       'heatindex_f': 22.9,
#       'dewpoint_c': -10.2,
#       'dewpoint_f': 13.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 12.2,
#       'gust_kph': 19.6,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1767085200,
#       'time': '2025-12-30 04:00',
#       'temp_c': -5.6,
#       'temp_f': 22.0,
#       'is_day': 0,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#        'code': 1009},
#       'wind_mph': 9.6,
#       'wind_kph': 15.5,
#       'wind_degree': 300,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1026.0,
#       'pressure_in': 30.31,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 69,
#       'cloud': 100,
#       'feelslike_c': -11.8,
#       'feelslike_f': 10.7,
#       'windchill_c': -11.8,
#       'windchill_f': 10.7,
#       'heatindex_c': -5.6,
#       'heatindex_f': 22.0,
#       'dewpoint_c': -10.1,
#       'dewpoint_f': 13.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.6,
#       'gust_kph': 18.7,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1767088800,
#       'time': '2025-12-30 05:00',
#       'temp_c': -6.0,
#       'temp_f': 21.1,
#       'is_day': 0,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#        'code': 1009},
#       'wind_mph': 9.4,
#       'wind_kph': 15.1,
#       'wind_degree': 302,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1027.0,
#       'pressure_in': 30.31,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 69,
#       'cloud': 88,
#       'feelslike_c': -12.4,
#       'feelslike_f': 9.7,
#       'windchill_c': -12.4,
#       'windchill_f': 9.7,
#       'heatindex_c': -6.0,
#       'heatindex_f': 21.1,
#       'dewpoint_c': -10.9,
#       'dewpoint_f': 12.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.4,
#       'gust_kph': 18.4,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1767092400,
#       'time': '2025-12-30 06:00',
#       'temp_c': -6.4,
#       'temp_f': 20.5,
#       'is_day': 0,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#        'code': 1009},
#       'wind_mph': 8.7,
#       'wind_kph': 14.0,
#       'wind_degree': 298,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1026.0,
#       'pressure_in': 30.3,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 69,
#       'cloud': 100,
#       'feelslike_c': -12.7,
#       'feelslike_f': 9.2,
#       'windchill_c': -12.7,
#       'windchill_f': 9.2,
#       'heatindex_c': -6.4,
#       'heatindex_f': 20.5,
#       'dewpoint_c': -11.2,
#       'dewpoint_f': 11.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.6,
#       'gust_kph': 17.1,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1767096000,
#       'time': '2025-12-30 07:00',
#       'temp_c': -6.7,
#       'temp_f': 19.9,
#       'is_day': 0,
#       'condition': {'text': 'Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png',
#        'code': 1006},
#       'wind_mph': 8.9,
#       'wind_kph': 14.4,
#       'wind_degree': 295,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1027.0,
#       'pressure_in': 30.32,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 67,
#       'cloud': 84,
#       'feelslike_c': -12.7,
#       'feelslike_f': 9.2,
#       'windchill_c': -12.7,
#       'windchill_f': 9.2,
#       'heatindex_c': -6.7,
#       'heatindex_f': 19.9,
#       'dewpoint_c': -11.8,
#       'dewpoint_f': 10.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.0,
#       'gust_kph': 17.6,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1767099600,
#       'time': '2025-12-30 08:00',
#       'temp_c': -7.1,
#       'temp_f': 19.2,
#       'is_day': 0,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 8.5,
#       'wind_kph': 13.7,
#       'wind_degree': 295,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1027.0,
#       'pressure_in': 30.33,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 67,
#       'cloud': 28,
#       'feelslike_c': -12.6,
#       'feelslike_f': 9.3,
#       'windchill_c': -12.6,
#       'windchill_f': 9.3,
#       'heatindex_c': -7.1,
#       'heatindex_f': 19.2,
#       'dewpoint_c': -12.2,
#       'dewpoint_f': 10.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.5,
#       'gust_kph': 16.8,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1767103200,
#       'time': '2025-12-30 09:00',
#       'temp_c': -7.3,
#       'temp_f': 18.9,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 8.5,
#       'wind_kph': 13.7,
#       'wind_degree': 296,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1027.0,
#       'pressure_in': 30.33,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 69,
#       'cloud': 11,
#       'feelslike_c': -12.8,
#       'feelslike_f': 8.9,
#       'windchill_c': -12.8,
#       'windchill_f': 8.9,
#       'heatindex_c': -7.3,
#       'heatindex_f': 18.9,
#       'dewpoint_c': -12.2,
#       'dewpoint_f': 10.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.5,
#       'gust_kph': 16.9,
#       'uv': 0.2,
#       'short_rad': 22.24,
#       'diff_rad': 8.33,
#       'dni': 31.52,
#       'gti': 2.29},
#      {'time_epoch': 1767106800,
#       'time': '2025-12-30 10:00',
#       'temp_c': -6.9,
#       'temp_f': 19.5,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 8.5,
#       'wind_kph': 13.7,
#       'wind_degree': 292,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1028.0,
#       'pressure_in': 30.34,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 69,
#       'cloud': 19,
#       'feelslike_c': -12.5,
#       'feelslike_f': 9.5,
#       'windchill_c': -12.5,
#       'windchill_f': 9.5,
#       'heatindex_c': -6.9,
#       'heatindex_f': 19.5,
#       'dewpoint_c': -12.1,
#       'dewpoint_f': 10.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.2,
#       'gust_kph': 16.3,
#       'uv': 0.7,
#       'short_rad': 80.94,
#       'diff_rad': 21.92,
#       'dni': 164.58,
#       'gti': 0.0},
#      {'time_epoch': 1767110400,
#       'time': '2025-12-30 11:00',
#       'temp_c': -6.2,
#       'temp_f': 20.9,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 8.7,
#       'wind_kph': 14.0,
#       'wind_degree': 297,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1028.0,
#       'pressure_in': 30.37,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 67,
#       'cloud': 22,
#       'feelslike_c': -11.7,
#       'feelslike_f': 10.9,
#       'windchill_c': -11.7,
#       'windchill_f': 10.9,
#       'heatindex_c': -6.2,
#       'heatindex_f': 20.9,
#       'dewpoint_c': -11.7,
#       'dewpoint_f': 10.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.0,
#       'gust_kph': 16.2,
#       'uv': 1.2,
#       'short_rad': 146.44,
#       'diff_rad': 32.86,
#       'dni': 483.66,
#       'gti': 0.0},
#      {'time_epoch': 1767114000,
#       'time': '2025-12-30 12:00',
#       'temp_c': -5.1,
#       'temp_f': 22.9,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 7.6,
#       'wind_kph': 12.2,
#       'wind_degree': 282,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1027.0,
#       'pressure_in': 30.34,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 62,
#       'cloud': 18,
#       'feelslike_c': -10.5,
#       'feelslike_f': 13.1,
#       'windchill_c': -10.5,
#       'windchill_f': 13.1,
#       'heatindex_c': -5.1,
#       'heatindex_f': 22.9,
#       'dewpoint_c': -11.6,
#       'dewpoint_f': 11.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 8.7,
#       'gust_kph': 14.1,
#       'uv': 1.7,
#       'short_rad': 205.88,
#       'diff_rad': 40.95,
#       'dni': 2101.08,
#       'gti': 0.0},
#      {'time_epoch': 1767117600,
#       'time': '2025-12-30 13:00',
#       'temp_c': -3.9,
#       'temp_f': 24.9,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 8.3,
#       'wind_kph': 13.3,
#       'wind_degree': 279,
#       'wind_dir': 'W',
#       'pressure_mb': 1027.0,
#       'pressure_in': 30.32,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 57,
#       'cloud': 9,
#       'feelslike_c': -9.1,
#       'feelslike_f': 15.5,
#       'windchill_c': -9.1,
#       'windchill_f': 15.5,
#       'heatindex_c': -3.9,
#       'heatindex_f': 24.9,
#       'dewpoint_c': -11.2,
#       'dewpoint_f': 11.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 9.5,
#       'gust_kph': 15.3,
#       'uv': 1.8,
#       'short_rad': 253.08,
#       'diff_rad': 46.86,
#       'dni': 0.0,
#       'gti': 47.26},
#      {'time_epoch': 1767121200,
#       'time': '2025-12-30 14:00',
#       'temp_c': -2.8,
#       'temp_f': 26.9,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 8.9,
#       'wind_kph': 14.4,
#       'wind_degree': 274,
#       'wind_dir': 'W',
#       'pressure_mb': 1026.0,
#       'pressure_in': 30.29,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 57,
#       'cloud': 7,
#       'feelslike_c': -7.7,
#       'feelslike_f': 18.2,
#       'windchill_c': -7.7,
#       'windchill_f': 18.2,
#       'heatindex_c': -2.8,
#       'heatindex_f': 26.9,
#       'dewpoint_c': -10.2,
#       'dewpoint_f': 13.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.3,
#       'gust_kph': 16.6,
#       'uv': 1.5,
#       'short_rad': 453.88,
#       'diff_rad': 108.55,
#       'dni': 0.0,
#       'gti': 106.64},
#      {'time_epoch': 1767124800,
#       'time': '2025-12-30 15:00',
#       'temp_c': -1.8,
#       'temp_f': 28.7,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 9.4,
#       'wind_kph': 15.1,
#       'wind_degree': 273,
#       'wind_dir': 'W',
#       'pressure_mb': 1025.0,
#       'pressure_in': 30.25,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 54,
#       'cloud': 5,
#       'feelslike_c': -6.5,
#       'feelslike_f': 20.3,
#       'windchill_c': -6.5,
#       'windchill_f': 20.3,
#       'heatindex_c': -1.8,
#       'heatindex_f': 28.7,
#       'dewpoint_c': -9.7,
#       'dewpoint_f': 14.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.8,
#       'gust_kph': 17.4,
#       'uv': 0.9,
#       'short_rad': 385.66,
#       'diff_rad': 122.67,
#       'dni': 0.0,
#       'gti': 117.78},
#      {'time_epoch': 1767128400,
#       'time': '2025-12-30 16:00',
#       'temp_c': -0.9,
#       'temp_f': 30.4,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 9.8,
#       'wind_kph': 15.8,
#       'wind_degree': 275,
#       'wind_dir': 'W',
#       'pressure_mb': 1024.0,
#       'pressure_in': 30.23,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 52,
#       'cloud': 2,
#       'feelslike_c': -5.3,
#       'feelslike_f': 22.4,
#       'windchill_c': -5.3,
#       'windchill_f': 22.4,
#       'heatindex_c': -0.9,
#       'heatindex_f': 30.4,
#       'dewpoint_c': -9.4,
#       'dewpoint_f': 15.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.9,
#       'gust_kph': 19.1,
#       'uv': 0.4,
#       'short_rad': 339.7,
#       'diff_rad': 109.78,
#       'dni': 0.0,
#       'gti': 105.28},
#      {'time_epoch': 1767132000,
#       'time': '2025-12-30 17:00',
#       'temp_c': -1.1,
#       'temp_f': 30.0,
#       'is_day': 1,
#       'condition': {'text': 'Overcast',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#        'code': 1009},
#       'wind_mph': 9.4,
#       'wind_kph': 15.1,
#       'wind_degree': 273,
#       'wind_dir': 'W',
#       'pressure_mb': 1022.0,
#       'pressure_in': 30.19,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 43,
#       'cloud': 100,
#       'feelslike_c': -4.5,
#       'feelslike_f': 23.9,
#       'windchill_c': -4.5,
#       'windchill_f': 23.9,
#       'heatindex_c': -0.3,
#       'heatindex_f': 31.5,
#       'dewpoint_c': -8.4,
#       'dewpoint_f': 16.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 16.0,
#       'vis_miles': 9.0,
#       'gust_mph': 11.9,
#       'gust_kph': 19.1,
#       'uv': 0.0,
#       'short_rad': 278.58,
#       'diff_rad': 93.19,
#       'dni': 0.0,
#       'gti': 89.17},
#      {'time_epoch': 1767135600,
#       'time': '2025-12-30 18:00',
#       'temp_c': -1.3,
#       'temp_f': 29.7,
#       'is_day': 0,
#       'condition': {'text': 'Clear ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 8.3,
#       'wind_kph': 13.3,
#       'wind_degree': 268,
#       'wind_dir': 'W',
#       'pressure_mb': 1023.0,
#       'pressure_in': 30.21,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 57,
#       'cloud': 0,
#       'feelslike_c': -5.8,
#       'feelslike_f': 21.6,
#       'windchill_c': -5.8,
#       'windchill_f': 21.6,
#       'heatindex_c': -1.3,
#       'heatindex_f': 29.7,
#       'dewpoint_c': -7.2,
#       'dewpoint_f': 19.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.3,
#       'gust_kph': 18.3,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1767139200,
#       'time': '2025-12-30 19:00',
#       'temp_c': -1.9,
#       'temp_f': 28.7,
#       'is_day': 0,
#       'condition': {'text': 'Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png',
#        'code': 1006},
#       'wind_mph': 7.8,
#       'wind_kph': 12.6,
#       'wind_degree': 259,
#       'wind_dir': 'W',
#       'pressure_mb': 1023.0,
#       'pressure_in': 30.21,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 56,
#       'cloud': 68,
#       'feelslike_c': -6.7,
#       'feelslike_f': 19.9,
#       'windchill_c': -6.7,
#       'windchill_f': 19.9,
#       'heatindex_c': -1.9,
#       'heatindex_f': 28.7,
#       'dewpoint_c': -9.9,
#       'dewpoint_f': 14.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.1,
#       'gust_kph': 17.9,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1767142800,
#       'time': '2025-12-30 20:00',
#       'temp_c': -2.3,
#       'temp_f': 27.9,
#       'is_day': 0,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#        'code': 1009},
#       'wind_mph': 7.6,
#       'wind_kph': 12.2,
#       'wind_degree': 251,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1022.0,
#       'pressure_in': 30.18,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 55,
#       'cloud': 100,
#       'feelslike_c': -7.4,
#       'feelslike_f': 18.7,
#       'windchill_c': -7.4,
#       'windchill_f': 18.7,
#       'heatindex_c': -2.3,
#       'heatindex_f': 27.9,
#       'dewpoint_c': -10.2,
#       'dewpoint_f': 13.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.5,
#       'gust_kph': 17.0,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1767146400,
#       'time': '2025-12-30 21:00',
#       'temp_c': -2.6,
#       'temp_f': 27.3,
#       'is_day': 0,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#        'code': 1009},
#       'wind_mph': 7.8,
#       'wind_kph': 12.6,
#       'wind_degree': 245,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1021.0,
#       'pressure_in': 30.16,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 57,
#       'cloud': 53,
#       'feelslike_c': -7.9,
#       'feelslike_f': 17.9,
#       'windchill_c': -7.9,
#       'windchill_f': 17.9,
#       'heatindex_c': -2.6,
#       'heatindex_f': 27.3,
#       'dewpoint_c': -10.0,
#       'dewpoint_f': 14.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.7,
#       'gust_kph': 17.2,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1767150000,
#       'time': '2025-12-30 22:00',
#       'temp_c': -1.9,
#       'temp_f': 28.6,
#       'is_day': 0,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#        'code': 1009},
#       'wind_mph': 8.3,
#       'wind_kph': 13.3,
#       'wind_degree': 239,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1021.0,
#       'pressure_in': 30.15,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 58,
#       'cloud': 30,
#       'feelslike_c': -6.7,
#       'feelslike_f': 19.9,
#       'windchill_c': -6.7,
#       'windchill_f': 19.9,
#       'heatindex_c': -1.9,
#       'heatindex_f': 28.6,
#       'dewpoint_c': -9.9,
#       'dewpoint_f': 14.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.3,
#       'gust_kph': 18.2,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1767153600,
#       'time': '2025-12-30 23:00',
#       'temp_c': -2.6,
#       'temp_f': 27.4,
#       'is_day': 0,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 8.5,
#       'wind_kph': 13.7,
#       'wind_degree': 239,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1021.0,
#       'pressure_in': 30.15,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 40,
#       'cloud': 49,
#       'feelslike_c': -7.9,
#       'feelslike_f': 17.8,
#       'windchill_c': -7.9,
#       'windchill_f': 17.8,
#       'heatindex_c': -2.6,
#       'heatindex_f': 27.4,
#       'dewpoint_c': -13.1,
#       'dewpoint_f': 8.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.9,
#       'gust_kph': 19.1,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0}]},
#    {'date': '2025-12-31',
#     'date_epoch': 1767139200,
#     'day': {'maxtemp_c': 4.2,
#      'maxtemp_f': 39.6,
#      'mintemp_c': -3.7,
#      'mintemp_f': 25.3,
#      'avgtemp_c': -0.7,
#      'avgtemp_f': 30.8,
#      'maxwind_mph': 10.3,
#      'maxwind_kph': 16.6,
#      'totalprecip_mm': 0.0,
#      'totalprecip_in': 0.0,
#      'totalsnow_cm': 0.0,
#      'avgvis_km': 10.0,
#      'avgvis_miles': 6.0,
#      'avghumidity': 64,
#      'daily_will_it_rain': 0,
#      'daily_chance_of_rain': 0,
#      'daily_will_it_snow': 0,
#      'daily_chance_of_snow': 0,
#      'condition': {'text': 'Cloudy ',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#       'code': 1006},
#      'uv': 0.4},
#     'astro': {'sunrise': '08:00 AM',
#      'sunset': '05:33 PM',
#      'moonrise': '02:36 PM',
#      'moonset': '05:05 AM',
#      'moon_phase': 'Waxing Gibbous',
#      'moon_illumination': 84,
#      'is_moon_up': 1,
#      'is_sun_up': 0},
#     'hour': [{'time_epoch': 1767157200,
#       'time': '2025-12-31 00:00',
#       'temp_c': -2.9,
#       'temp_f': 26.7,
#       'is_day': 0,
#       'condition': {'text': 'Clear ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 9.2,
#       'wind_kph': 14.8,
#       'wind_degree': 238,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1019.0,
#       'pressure_in': 30.1,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 60,
#       'cloud': 3,
#       'feelslike_c': -8.6,
#       'feelslike_f': 16.6,
#       'windchill_c': -8.6,
#       'windchill_f': 16.6,
#       'heatindex_c': -2.9,
#       'heatindex_f': 26.7,
#       'dewpoint_c': -9.9,
#       'dewpoint_f': 14.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 13.0,
#       'gust_kph': 20.9,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1767160800,
#       'time': '2025-12-31 01:00',
#       'temp_c': -3.2,
#       'temp_f': 26.3,
#       'is_day': 0,
#       'condition': {'text': 'Clear ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 9.4,
#       'wind_kph': 15.1,
#       'wind_degree': 235,
#       'wind_dir': 'SW',
#       'pressure_mb': 1019.0,
#       'pressure_in': 30.09,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 60,
#       'cloud': 2,
#       'feelslike_c': -9.0,
#       'feelslike_f': 15.7,
#       'windchill_c': -9.0,
#       'windchill_f': 15.7,
#       'heatindex_c': -3.2,
#       'heatindex_f': 26.3,
#       'dewpoint_c': -9.9,
#       'dewpoint_f': 14.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 13.5,
#       'gust_kph': 21.8,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1767164400,
#       'time': '2025-12-31 02:00',
#       'temp_c': -3.4,
#       'temp_f': 26.0,
#       'is_day': 0,
#       'condition': {'text': 'Clear ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 9.8,
#       'wind_kph': 15.8,
#       'wind_degree': 233,
#       'wind_dir': 'SW',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.07,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 61,
#       'cloud': 0,
#       'feelslike_c': -9.3,
#       'feelslike_f': 15.3,
#       'windchill_c': -9.3,
#       'windchill_f': 15.3,
#       'heatindex_c': -3.4,
#       'heatindex_f': 26.0,
#       'dewpoint_c': -9.9,
#       'dewpoint_f': 14.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 14.4,
#       'gust_kph': 23.2,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1767168000,
#       'time': '2025-12-31 03:00',
#       'temp_c': -3.5,
#       'temp_f': 25.7,
#       'is_day': 0,
#       'condition': {'text': 'Clear ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 10.1,
#       'wind_kph': 16.2,
#       'wind_degree': 234,
#       'wind_dir': 'SW',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.04,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 63,
#       'cloud': 0,
#       'feelslike_c': -9.4,
#       'feelslike_f': 15.1,
#       'windchill_c': -9.4,
#       'windchill_f': 15.1,
#       'heatindex_c': -3.5,
#       'heatindex_f': 25.7,
#       'dewpoint_c': -9.6,
#       'dewpoint_f': 14.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 14.8,
#       'gust_kph': 23.9,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1767171600,
#       'time': '2025-12-31 04:00',
#       'temp_c': -3.6,
#       'temp_f': 25.5,
#       'is_day': 0,
#       'condition': {'text': 'Clear ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 10.3,
#       'wind_kph': 16.6,
#       'wind_degree': 237,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.03,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 64,
#       'cloud': 0,
#       'feelslike_c': -9.4,
#       'feelslike_f': 15.0,
#       'windchill_c': -9.4,
#       'windchill_f': 15.0,
#       'heatindex_c': -3.6,
#       'heatindex_f': 25.5,
#       'dewpoint_c': -9.5,
#       'dewpoint_f': 14.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 15.4,
#       'gust_kph': 24.8,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1767175200,
#       'time': '2025-12-31 05:00',
#       'temp_c': -3.4,
#       'temp_f': 25.8,
#       'is_day': 0,
#       'condition': {'text': 'Clear ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 10.1,
#       'wind_kph': 16.2,
#       'wind_degree': 239,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.02,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 65,
#       'cloud': 0,
#       'feelslike_c': -9.1,
#       'feelslike_f': 15.5,
#       'windchill_c': -9.1,
#       'windchill_f': 15.5,
#       'heatindex_c': -3.4,
#       'heatindex_f': 25.8,
#       'dewpoint_c': -9.4,
#       'dewpoint_f': 15.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 15.0,
#       'gust_kph': 24.1,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1767178800,
#       'time': '2025-12-31 06:00',
#       'temp_c': -3.2,
#       'temp_f': 26.2,
#       'is_day': 0,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 9.6,
#       'wind_kph': 15.5,
#       'wind_degree': 243,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.02,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 64,
#       'cloud': 33,
#       'feelslike_c': -8.8,
#       'feelslike_f': 16.1,
#       'windchill_c': -8.8,
#       'windchill_f': 16.1,
#       'heatindex_c': -3.2,
#       'heatindex_f': 26.2,
#       'dewpoint_c': -9.0,
#       'dewpoint_f': 15.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 14.2,
#       'gust_kph': 22.8,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1767182400,
#       'time': '2025-12-31 07:00',
#       'temp_c': -3.0,
#       'temp_f': 26.6,
#       'is_day': 0,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 8.7,
#       'wind_kph': 14.0,
#       'wind_degree': 245,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.02,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 64,
#       'cloud': 49,
#       'feelslike_c': -8.5,
#       'feelslike_f': 16.7,
#       'windchill_c': -8.5,
#       'windchill_f': 16.7,
#       'heatindex_c': -3.0,
#       'heatindex_f': 26.6,
#       'dewpoint_c': -8.9,
#       'dewpoint_f': 16.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 12.8,
#       'gust_kph': 20.6,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1767186000,
#       'time': '2025-12-31 08:00',
#       'temp_c': -2.5,
#       'temp_f': 27.5,
#       'is_day': 0,
#       'condition': {'text': 'Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png',
#        'code': 1006},
#       'wind_mph': 8.1,
#       'wind_kph': 13.0,
#       'wind_degree': 246,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.02,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 64,
#       'cloud': 65,
#       'feelslike_c': -7.9,
#       'feelslike_f': 17.9,
#       'windchill_c': -7.9,
#       'windchill_f': 17.9,
#       'heatindex_c': -2.5,
#       'heatindex_f': 27.5,
#       'dewpoint_c': -8.7,
#       'dewpoint_f': 16.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.9,
#       'gust_kph': 19.2,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1767189600,
#       'time': '2025-12-31 09:00',
#       'temp_c': -2.1,
#       'temp_f': 28.3,
#       'is_day': 1,
#       'condition': {'text': 'Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#        'code': 1006},
#       'wind_mph': 7.2,
#       'wind_kph': 11.5,
#       'wind_degree': 249,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.02,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 61,
#       'cloud': 38,
#       'feelslike_c': -7.3,
#       'feelslike_f': 18.9,
#       'windchill_c': -7.3,
#       'windchill_f': 18.9,
#       'heatindex_c': -2.1,
#       'heatindex_f': 28.3,
#       'dewpoint_c': -8.5,
#       'dewpoint_f': 16.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.6,
#       'gust_kph': 17.1,
#       'uv': 0.2,
#       'short_rad': 18.62,
#       'diff_rad': 8.54,
#       'dni': 22.75,
#       'gti': 4.0},
#      {'time_epoch': 1767193200,
#       'time': '2025-12-31 10:00',
#       'temp_c': -1.6,
#       'temp_f': 29.1,
#       'is_day': 1,
#       'condition': {'text': 'Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#        'code': 1006},
#       'wind_mph': 7.6,
#       'wind_kph': 12.2,
#       'wind_degree': 239,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.02,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 60,
#       'cloud': 24,
#       'feelslike_c': -6.8,
#       'feelslike_f': 19.8,
#       'windchill_c': -6.8,
#       'windchill_f': 19.8,
#       'heatindex_c': -1.6,
#       'heatindex_f': 29.1,
#       'dewpoint_c': -8.4,
#       'dewpoint_f': 16.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.1,
#       'gust_kph': 16.3,
#       'uv': 0.7,
#       'short_rad': 61.34,
#       'diff_rad': 28.32,
#       'dni': 91.6,
#       'gti': 8.13},
#      {'time_epoch': 1767196800,
#       'time': '2025-12-31 11:00',
#       'temp_c': -0.3,
#       'temp_f': 31.5,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 8.3,
#       'wind_kph': 13.3,
#       'wind_degree': 251,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.02,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 58,
#       'cloud': 10,
#       'feelslike_c': -5.2,
#       'feelslike_f': 22.7,
#       'windchill_c': -5.2,
#       'windchill_f': 22.7,
#       'heatindex_c': -0.3,
#       'heatindex_f': 31.5,
#       'dewpoint_c': -8.3,
#       'dewpoint_f': 17.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.4,
#       'gust_kph': 16.8,
#       'uv': 1.4,
#       'short_rad': 128.26,
#       'diff_rad': 40.59,
#       'dni': 369.98,
#       'gti': 0.0},
#      {'time_epoch': 1767200400,
#       'time': '2025-12-31 12:00',
#       'temp_c': 1.0,
#       'temp_f': 33.8,
#       'is_day': 1,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 8.9,
#       'wind_kph': 14.4,
#       'wind_degree': 251,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1016.0,
#       'pressure_in': 29.99,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 56,
#       'cloud': 40,
#       'feelslike_c': -3.7,
#       'feelslike_f': 25.3,
#       'windchill_c': -3.7,
#       'windchill_f': 25.3,
#       'heatindex_c': 1.0,
#       'heatindex_f': 33.8,
#       'dewpoint_c': -6.6,
#       'dewpoint_f': 20.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.6,
#       'gust_kph': 17.0,
#       'uv': 1.9,
#       'short_rad': 182.04,
#       'diff_rad': 58.1,
#       'dni': 1534.7,
#       'gti': 0.0},
#      {'time_epoch': 1767204000,
#       'time': '2025-12-31 13:00',
#       'temp_c': 2.2,
#       'temp_f': 36.0,
#       'is_day': 1,
#       'condition': {'text': 'Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#        'code': 1006},
#       'wind_mph': 9.8,
#       'wind_kph': 15.8,
#       'wind_degree': 257,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.98,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 55,
#       'cloud': 55,
#       'feelslike_c': -2.3,
#       'feelslike_f': 27.8,
#       'windchill_c': -2.3,
#       'windchill_f': 27.8,
#       'heatindex_c': 2.2,
#       'heatindex_f': 36.0,
#       'dewpoint_c': -5.8,
#       'dewpoint_f': 21.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.7,
#       'gust_kph': 18.8,
#       'uv': 1.9,
#       'short_rad': 218.08,
#       'diff_rad': 75.81,
#       'dni': 0.0,
#       'gti': 72.35},
#      {'time_epoch': 1767207600,
#       'time': '2025-12-31 14:00',
#       'temp_c': 3.0,
#       'temp_f': 37.4,
#       'is_day': 1,
#       'condition': {'text': 'Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#        'code': 1006},
#       'wind_mph': 10.3,
#       'wind_kph': 16.6,
#       'wind_degree': 263,
#       'wind_dir': 'W',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.96,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 54,
#       'cloud': 70,
#       'feelslike_c': -1.4,
#       'feelslike_f': 29.6,
#       'windchill_c': -1.4,
#       'windchill_f': 29.6,
#       'heatindex_c': 3.0,
#       'heatindex_f': 37.4,
#       'dewpoint_c': -5.0,
#       'dewpoint_f': 23.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 12.3,
#       'gust_kph': 19.8,
#       'uv': 1.6,
#       'short_rad': 333.9,
#       'diff_rad': 160.98,
#       'dni': 0.0,
#       'gti': 150.86},
#      {'time_epoch': 1767211200,
#       'time': '2025-12-31 15:00',
#       'temp_c': 3.5,
#       'temp_f': 38.3,
#       'is_day': 1,
#       'condition': {'text': 'Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#        'code': 1006},
#       'wind_mph': 9.8,
#       'wind_kph': 15.8,
#       'wind_degree': 258,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.95,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 57,
#       'cloud': 85,
#       'feelslike_c': -0.7,
#       'feelslike_f': 30.7,
#       'windchill_c': -0.7,
#       'windchill_f': 30.7,
#       'heatindex_c': 3.5,
#       'heatindex_f': 38.3,
#       'dewpoint_c': -4.0,
#       'dewpoint_f': 24.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 12.1,
#       'gust_kph': 19.5,
#       'uv': 1.0,
#       'short_rad': 275.52,
#       'diff_rad': 135.82,
#       'dni': 0.0,
#       'gti': 127.16},
#      {'time_epoch': 1767214800,
#       'time': '2025-12-31 16:00',
#       'temp_c': 3.8,
#       'temp_f': 38.9,
#       'is_day': 1,
#       'condition': {'text': 'Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#        'code': 1006},
#       'wind_mph': 9.2,
#       'wind_kph': 14.8,
#       'wind_degree': 259,
#       'wind_dir': 'W',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.94,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 58,
#       'cloud': 92,
#       'feelslike_c': -0.3,
#       'feelslike_f': 31.5,
#       'windchill_c': -0.3,
#       'windchill_f': 31.5,
#       'heatindex_c': 3.8,
#       'heatindex_f': 38.9,
#       'dewpoint_c': -3.5,
#       'dewpoint_f': 25.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.7,
#       'gust_kph': 18.9,
#       'uv': 0.4,
#       'short_rad': 231.56,
#       'diff_rad': 114.99,
#       'dni': 0.0,
#       'gti': 107.62},
#      {'time_epoch': 1767218400,
#       'time': '2025-12-31 17:00',
#       'temp_c': 3.0,
#       'temp_f': 37.4,
#       'is_day': 1,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#        'code': 1009},
#       'wind_mph': 9.8,
#       'wind_kph': 15.8,
#       'wind_degree': 268,
#       'wind_dir': 'W',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.93,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 59,
#       'cloud': 99,
#       'feelslike_c': -1.0,
#       'feelslike_f': 30.3,
#       'windchill_c': -1.0,
#       'windchill_f': 30.3,
#       'heatindex_c': 3.0,
#       'heatindex_f': 37.4,
#       'dewpoint_c': -3.0,
#       'dewpoint_f': 26.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 13.1,
#       'gust_kph': 21.1,
#       'uv': 0.0,
#       'short_rad': 192.68,
#       'diff_rad': 95.54,
#       'dni': 0.0,
#       'gti': 89.42},
#      {'time_epoch': 1767222000,
#       'time': '2025-12-31 18:00',
#       'temp_c': 2.1,
#       'temp_f': 35.8,
#       'is_day': 0,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#        'code': 1009},
#       'wind_mph': 8.9,
#       'wind_kph': 14.4,
#       'wind_degree': 268,
#       'wind_dir': 'W',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.95,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 70,
#       'cloud': 56,
#       'feelslike_c': -1.7,
#       'feelslike_f': 28.9,
#       'windchill_c': -1.7,
#       'windchill_f': 28.9,
#       'heatindex_c': 2.1,
#       'heatindex_f': 35.8,
#       'dewpoint_c': -2.8,
#       'dewpoint_f': 26.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 12.7,
#       'gust_kph': 20.4,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1767225600,
#       'time': '2025-12-31 19:00',
#       'temp_c': 1.2,
#       'temp_f': 34.1,
#       'is_day': 0,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#        'code': 1009},
#       'wind_mph': 8.7,
#       'wind_kph': 14.0,
#       'wind_degree': 260,
#       'wind_dir': 'W',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.96,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 76,
#       'cloud': 34,
#       'feelslike_c': -2.6,
#       'feelslike_f': 27.3,
#       'windchill_c': -2.6,
#       'windchill_f': 27.3,
# ...
#       'humidity': 87,
#       'cloud': 74,
#       'feelslike_c': -3.6,
#       'feelslike_f': 25.5,
#       'windchill_c': -3.6,
#       'windchill_f': 25.5,
#       'heatindex_c': -1.0,
#       'heatindex_f': 30.2,
#       'dewpoint_c': -3.3,
#       'dewpoint_f': 26.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 6.5,
#       'gust_kph': 10.4,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1767276000,
#       'time': '2026-01-01 09:00',
#       'temp_c': -0.6,
#       'temp_f': 30.9,
#       'is_day': 1,
#       'condition': {'text': 'Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#        'code': 1006},
#       'wind_mph': 4.0,
#       'wind_kph': 6.5,
#       'wind_degree': 296,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1019.0,
#       'pressure_in': 30.09,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 87,
#       'cloud': 87,
#       'feelslike_c': -3.4,
#       'feelslike_f': 26.0,
#       'windchill_c': -3.4,
#       'windchill_f': 26.0,
#       'heatindex_c': -0.6,
#       'heatindex_f': 30.9,
#       'dewpoint_c': -2.6,
#       'dewpoint_f': 27.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.6,
#       'gust_kph': 9.0,
#       'uv': 1.0,
#       'short_rad': 19.84,
#       'diff_rad': 8.7,
#       'dni': 25.06,
#       'gti': 3.79},
#      {'time_epoch': 1767279600,
#       'time': '2026-01-01 10:00',
#       'temp_c': -0.3,
#       'temp_f': 31.5,
#       'is_day': 1,
#       'condition': {'text': 'Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#        'code': 1006},
#       'wind_mph': 3.8,
#       'wind_kph': 6.1,
#       'wind_degree': 304,
#       'wind_dir': 'NW',
#       'pressure_mb': 1019.0,
#       'pressure_in': 30.1,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 87,
#       'cloud': 93,
#       'feelslike_c': -3.1,
#       'feelslike_f': 26.3,
#       'windchill_c': -3.1,
#       'windchill_f': 26.3,
#       'heatindex_c': -0.3,
#       'heatindex_f': 31.5,
#       'dewpoint_c': -2.2,
#       'dewpoint_f': 28.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.8,
#       'gust_kph': 7.7,
#       'uv': 1.0,
#       'short_rad': 74.66,
#       'diff_rad': 25.1,
#       'dni': 136.71,
#       'gti': 0.0},
#      {'time_epoch': 1767283200,
#       'time': '2026-01-01 11:00',
#       'temp_c': 0.3,
#       'temp_f': 32.5,
#       'is_day': 1,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#        'code': 1009},
#       'wind_mph': 4.7,
#       'wind_kph': 7.6,
#       'wind_degree': 311,
#       'wind_dir': 'NW',
#       'pressure_mb': 1020.0,
#       'pressure_in': 30.11,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 86,
#       'cloud': 100,
#       'feelslike_c': -2.7,
#       'feelslike_f': 27.1,
#       'windchill_c': -2.7,
#       'windchill_f': 27.1,
#       'heatindex_c': 0.3,
#       'heatindex_f': 32.5,
#       'dewpoint_c': -1.9,
#       'dewpoint_f': 28.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.5,
#       'gust_kph': 8.9,
#       'uv': 1.0,
#       'short_rad': 136.84,
#       'diff_rad': 39.47,
#       'dni': 407.1,
#       'gti': 0.0},
#      {'time_epoch': 1767286800,
#       'time': '2026-01-01 12:00',
#       'temp_c': 0.7,
#       'temp_f': 33.3,
#       'is_day': 1,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#        'code': 1009},
#       'wind_mph': 3.8,
#       'wind_kph': 6.1,
#       'wind_degree': 301,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1019.0,
#       'pressure_in': 30.1,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 80,
#       'cloud': 99,
#       'feelslike_c': -2.3,
#       'feelslike_f': 27.8,
#       'windchill_c': -2.3,
#       'windchill_f': 27.8,
#       'heatindex_c': 0.7,
#       'heatindex_f': 33.3,
#       'dewpoint_c': -2.2,
#       'dewpoint_f': 28.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.4,
#       'gust_kph': 7.1,
#       'uv': 1.0,
#       'short_rad': 194.28,
#       'diff_rad': 50.06,
#       'dni': 1735.32,
#       'gti': 0.0},
#      {'time_epoch': 1767290400,
#       'time': '2026-01-01 13:00',
#       'temp_c': 1.1,
#       'temp_f': 34.0,
#       'is_day': 1,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#        'code': 1009},
#       'wind_mph': 4.9,
#       'wind_kph': 7.9,
#       'wind_degree': 279,
#       'wind_dir': 'W',
#       'pressure_mb': 1019.0,
#       'pressure_in': 30.1,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 77,
#       'cloud': 99,
#       'feelslike_c': -2.0,
#       'feelslike_f': 28.4,
#       'windchill_c': -2.0,
#       'windchill_f': 28.4,
#       'heatindex_c': 1.1,
#       'heatindex_f': 34.0,
#       'dewpoint_c': -2.4,
#       'dewpoint_f': 27.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.7,
#       'gust_kph': 9.1,
#       'uv': 1.0,
#       'short_rad': 240.14,
#       'diff_rad': 57.83,
#       'dni': 0.0,
#       'gti': 56.78},
#      {'time_epoch': 1767294000,
#       'time': '2026-01-01 14:00',
#       'temp_c': 1.4,
#       'temp_f': 34.5,
#       'is_day': 1,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#        'code': 1009},
#       'wind_mph': 5.4,
#       'wind_kph': 8.6,
#       'wind_degree': 273,
#       'wind_dir': 'W',
#       'pressure_mb': 1019.0,
#       'pressure_in': 30.09,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 74,
#       'cloud': 98,
#       'feelslike_c': -1.7,
#       'feelslike_f': 28.9,
#       'windchill_c': -1.7,
#       'windchill_f': 28.9,
#       'heatindex_c': 1.4,
#       'heatindex_f': 34.5,
#       'dewpoint_c': -2.5,
#       'dewpoint_f': 27.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 6.2,
#       'gust_kph': 9.9,
#       'uv': 1.0,
#       'short_rad': 455.4,
#       'diff_rad': 96.09,
#       'dni': 0.0,
#       'gti': 95.55},
#      {'time_epoch': 1767297600,
#       'time': '2026-01-01 15:00',
#       'temp_c': 1.6,
#       'temp_f': 34.9,
#       'is_day': 1,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#        'code': 1009},
#       'wind_mph': 5.6,
#       'wind_kph': 9.0,
#       'wind_degree': 279,
#       'wind_dir': 'W',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.07,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 74,
#       'cloud': 86,
#       'feelslike_c': -1.6,
#       'feelslike_f': 29.2,
#       'windchill_c': -1.6,
#       'windchill_f': 29.2,
#       'heatindex_c': 1.6,
#       'heatindex_f': 34.9,
#       'dewpoint_c': -2.4,
#       'dewpoint_f': 27.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 6.4,
#       'gust_kph': 10.4,
#       'uv': 1.0,
#       'short_rad': 420.02,
#       'diff_rad': 91.94,
#       'dni': 0.0,
#       'gti': 91.09},
#      {'time_epoch': 1767301200,
#       'time': '2026-01-01 16:00',
#       'temp_c': 1.8,
#       'temp_f': 35.2,
#       'is_day': 1,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#        'code': 1009},
#       'wind_mph': 5.6,
#       'wind_kph': 9.0,
#       'wind_degree': 277,
#       'wind_dir': 'W',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.06,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 74,
#       'cloud': 81,
#       'feelslike_c': -1.4,
#       'feelslike_f': 29.4,
#       'windchill_c': -1.4,
#       'windchill_f': 29.4,
#       'heatindex_c': 1.8,
#       'heatindex_f': 35.2,
#       'dewpoint_c': -2.4,
#       'dewpoint_f': 27.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 6.5,
#       'gust_kph': 10.4,
#       'uv': 1.0,
#       'short_rad': 368.48,
#       'diff_rad': 85.06,
#       'dni': 0.0,
#       'gti': 83.84},
#      {'time_epoch': 1767304800,
#       'time': '2026-01-01 17:00',
#       'temp_c': 1.4,
#       'temp_f': 34.6,
#       'is_day': 1,
#       'condition': {'text': 'Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#        'code': 1006},
#       'wind_mph': 5.8,
#       'wind_kph': 9.4,
#       'wind_degree': 279,
#       'wind_dir': 'W',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.05,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 73,
#       'cloud': 75,
#       'feelslike_c': -1.7,
#       'feelslike_f': 28.9,
#       'windchill_c': -1.7,
#       'windchill_f': 28.9,
#       'heatindex_c': 1.4,
#       'heatindex_f': 34.6,
#       'dewpoint_c': -2.3,
#       'dewpoint_f': 27.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 7.2,
#       'gust_kph': 11.6,
#       'uv': 1.0,
#       'short_rad': 302.4,
#       'diff_rad': 75.42,
#       'dni': 0.0,
#       'gti': 73.82},
#      {'time_epoch': 1767308400,
#       'time': '2026-01-01 18:00',
#       'temp_c': 1.1,
#       'temp_f': 33.9,
#       'is_day': 0,
#       'condition': {'text': 'Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png',
#        'code': 1006},
#       'wind_mph': 4.5,
#       'wind_kph': 7.2,
#       'wind_degree': 288,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.06,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 78,
#       'cloud': 79,
#       'feelslike_c': -2.0,
#       'feelslike_f': 28.3,
#       'windchill_c': -2.0,
#       'windchill_f': 28.3,
#       'heatindex_c': 1.1,
#       'heatindex_f': 33.9,
#       'dewpoint_c': -2.3,
#       'dewpoint_f': 27.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 6.6,
#       'gust_kph': 10.6,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1767312000,
#       'time': '2026-01-01 19:00',
#       'temp_c': 0.7,
#       'temp_f': 33.2,
#       'is_day': 0,
#       'condition': {'text': 'Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png',
#        'code': 1006},
#       'wind_mph': 3.1,
#       'wind_kph': 5.0,
#       'wind_degree': 284,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.06,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 80,
#       'cloud': 82,
#       'feelslike_c': -2.4,
#       'feelslike_f': 27.8,
#       'windchill_c': -2.4,
#       'windchill_f': 27.8,
#       'heatindex_c': 0.7,
#       'heatindex_f': 33.2,
#       'dewpoint_c': -2.3,
#       'dewpoint_f': 27.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.3,
#       'gust_kph': 8.5,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1767315600,
#       'time': '2026-01-01 20:00',
#       'temp_c': 0.5,
#       'temp_f': 33.0,
#       'is_day': 0,
#       'condition': {'text': 'Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png',
#        'code': 1006},
#       'wind_mph': 3.1,
#       'wind_kph': 5.0,
#       'wind_degree': 278,
#       'wind_dir': 'W',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.06,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 82,
#       'cloud': 84,
#       'feelslike_c': -1.6,
#       'feelslike_f': 29.2,
#       'windchill_c': -1.6,
#       'windchill_f': 29.2,
#       'heatindex_c': 0.5,
#       'heatindex_f': 33.0,
#       'dewpoint_c': -2.4,
#       'dewpoint_f': 27.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.3,
#       'gust_kph': 8.5,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1767319200,
#       'time': '2026-01-01 21:00',
#       'temp_c': 0.3,
#       'temp_f': 32.5,
#       'is_day': 0,
#       'condition': {'text': 'Clear ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 2.7,
#       'wind_kph': 4.3,
#       'wind_degree': 299,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.02,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 66,
#       'cloud': 8,
#       'feelslike_c': -1.5,
#       'feelslike_f': 29.3,
#       'windchill_c': -1.5,
#       'windchill_f': 29.3,
#       'heatindex_c': 0.3,
#       'heatindex_f': 32.5,
#       'dewpoint_c': -5.2,
#       'dewpoint_f': 22.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.5,
#       'gust_kph': 7.3,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1767322800,
#       'time': '2026-01-01 22:00',
#       'temp_c': -0.2,
#       'temp_f': 31.6,
#       'is_day': 0,
#       'condition': {'text': 'Clear ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 2.9,
#       'wind_kph': 4.7,
#       'wind_degree': 316,
#       'wind_dir': 'NW',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.02,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 67,
#       'cloud': 8,
#       'feelslike_c': -3.3,
#       'feelslike_f': 26.1,
#       'windchill_c': -3.3,
#       'windchill_f': 26.1,
#       'heatindex_c': -0.2,
#       'heatindex_f': 31.6,
#       'dewpoint_c': -5.5,
#       'dewpoint_f': 22.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.9,
#       'gust_kph': 7.9,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1767326400,
#       'time': '2026-01-01 23:00',
#       'temp_c': -0.4,
#       'temp_f': 31.4,
#       'is_day': 0,
#       'condition': {'text': 'Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png',
#        'code': 1006},
#       'wind_mph': 2.5,
#       'wind_kph': 4.0,
#       'wind_degree': 322,
#       'wind_dir': 'NW',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.01,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 84,
#       'cloud': 82,
#       'feelslike_c': -2.4,
#       'feelslike_f': 27.6,
#       'windchill_c': -2.4,
#       'windchill_f': 27.6,
#       'heatindex_c': -0.4,
#       'heatindex_f': 31.3,
#       'dewpoint_c': -3.0,
#       'dewpoint_f': 26.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.1,
#       'gust_kph': 6.7,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0}]}]}}

# %%
# Astronomy
today = pd.Timestamp.now().strftime('%Y-%m-%d')
astronomy_url = f"{baseurl}astronomy.json?key={api_key}&q={city}&dt={today}"
astronomy_response = requests.get(astronomy_url)

astronomy_response.status_code
# Out:
# 200

# %%
astronomy_response.json()
# Out:
# {'location': {'name': 'Louisville',
#   'region': 'Kentucky',
#   'country': 'United States of America',
#   'lat': 38.2542,
#   'lon': -85.7594,
#   'tz_id': 'America/Kentucky/Louisville',
#   'localtime_epoch': 1767132436,
#   'localtime': '2025-12-30 17:07'},
#  'astronomy': {'astro': {'sunrise': '08:00 AM',
#    'sunset': '05:32 PM',
#    'moonrise': '01:52 PM',
#    'moonset': '03:47 AM',
#    'moon_phase': 'Waxing Gibbous',
#    'moon_illumination': 76,
#    'is_moon_up': 0,
#    'is_sun_up': 1}}}

# %%
astro_data = astronomy_response.json()
astro_data['astronomy']
# Out:
# {'astro': {'sunrise': '08:00 AM',
#   'sunset': '05:32 PM',
#   'moonrise': '01:52 PM',
#   'moonset': '03:47 AM',
#   'moon_phase': 'Waxing Gibbous',
#   'moon_illumination': 76,
#   'is_moon_up': 0,
#   'is_sun_up': 1}}

# %%
astro = astro_data['astronomy']['astro']

astro_info = []

for rise_set in astro:
    astro_info.append(f"Sunrise: {astro['sunrise']}, Sunset: {astro['sunset']}")

astro_info
# Out:
# ['Sunrise: 08:00 AM, Sunset: 05:32 PM',
#  'Sunrise: 08:00 AM, Sunset: 05:32 PM',
#  'Sunrise: 08:00 AM, Sunset: 05:32 PM',
#  'Sunrise: 08:00 AM, Sunset: 05:32 PM',
#  'Sunrise: 08:00 AM, Sunset: 05:32 PM',
#  'Sunrise: 08:00 AM, Sunset: 05:32 PM',
#  'Sunrise: 08:00 AM, Sunset: 05:32 PM',
#  'Sunrise: 08:00 AM, Sunset: 05:32 PM']

# %%
# Other
other_url = f"{baseurl}other.json?key={api_key}&q=..."
other_response = requests.get(f"{baseurl}...")

# %%
other_response.json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /var/folders/rt/rt9sdyhn03b7bz7l20vpzlm40000gn/T/ipykernel_40526/370300308.py in <module>
# ----> 1 other_response.json()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/models.py in json(self, **kwargs)
#     908                     # used.
#     909                     pass
# --> 910         return complexjson.loads(self.text, **kwargs)
#     911
#     912     @property
#
# ~/opt/anaconda3/lib/python3.9/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     344             parse_int is None and parse_float is None and
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#     348         cls = JSONDecoder
#
# ~/opt/anaconda3/lib/python3.9/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~/opt/anaconda3/lib/python3.9/json/decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %% [markdown]
# ## Define the Function

# %%
def get_city_data(city, api_key):
    #Get current weather
    weather_url = f"http://api.weatherapi.com/v1/current.json?key={key}&q={city}"
    weather_response = requests.get(weather_url)
    if weather_response.status_code == 200:
        data = response.json()
        current = data['current']
        location = data['location']
        temp_f = current['temp_f']
        wind_mph = current['wind_mph']
        humidity = current['humidity']
        
        print(f"Weather for {location['name']}, {location['region']}")
        print(f"Temperature: {current['temp_f']} F / {current['temp_c']} C")
        print(f"Condition: {current['condition']['text']}")
        print(f"Humidity: {current['humidity']}%")
        print(f"Wind Speed: {current['wind_mph']} mph")
        
    else:
        Print(f"Error fetching data. There is no weather for {city}: {response.status_code}")

    # Get forecast
    forecast_3_day_summary = []
    
    for day in forecast:
        forecast_url = f"{baseurl}forecast.json?key={api_key}&q={city}&days=3"
        forecast_response = requests.get(forecast_url)
        
        date_obj = datetime.strptime(day['date], '%y-%m-%d')
        formatted_date = date_obj.strptime('%A,%B %#d')
        forecast_3_day_summary.append(f"{formatted_date}: High {day['day']['max_temp']}F / Low: {day['day']['min_temp']}F - {day['day']['condition']['text']})
    
 
    # Get astronomy
    today = pd.Timestamp.now().strftime('%Y-%m-%d')
    astronomy_url = f"{baseurl}astronomy.json?key={api_key}&q={city}&dt={today}"
    
    response = requests.get(f"{baseurl}astronomy.json?key={api_key}&q={city}&dt={today}")
    response.status_code
    
    for star in stars
 
    # Get other data ()
 
 
    
    # Build a summary dictionary of city/weather data
    city_summary = {}



    return city_summary


    # Save/export as a csv
    weather_df = pd.DataFrame(city_summary)
    
    weather_df.to_csv("sample_weather_data", index=False)
# Out:
#   File "<tokenize>", line 4
#     response = requests.get(url)
#     ^
# IndentationError: unindent does not match any outer indentation level

# %% [markdown]
# ### Test the Funciton

# %%
get_city_data("Las Vegas", API KEY)
