# %% [markdown]
# # Weather API

# %% [markdown]
# ## Package import

# %%
import pandas as pd
import requests

# %% [markdown]
# ## API Info

# %%
key = "<KEY HERE>"
# baseurl = http://api.weatherapi.com/v1

# %% [markdown]
# ## Work

# %%
city = "louisville"
baseurl = f"http://api.weatherapi.com/v1/current.json?key={key}&q={city}"
response = requests.get(baseurl)

# %%
response.status_code
# Out:
# 200

# %%
data = response.json()
data
# Out:
# {'location': {'name': 'Louisville',
#   'region': 'Kentucky',
#   'country': 'United States of America',
#   'lat': 38.2542,
#   'lon': -85.7594,
#   'tz_id': 'America/Kentucky/Louisville',
#   'localtime_epoch': 1767120121,
#   'localtime': '2025-12-30 13:42'},
#  'current': {'last_updated_epoch': 1767119400,
#   'last_updated': '2025-12-30 13:30',
#   'temp_c': -2.8,
#   'temp_f': 27.0,
#   'is_day': 1,
#   'condition': {'text': 'Sunny',
#    'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#    'code': 1000},
#   'wind_mph': 8.3,
#   'wind_kph': 13.3,
#   'wind_degree': 279,
#   'wind_dir': 'W',
#   'pressure_mb': 1024.0,
#   'pressure_in': 30.24,
#   'precip_mm': 0.0,
#   'precip_in': 0.0,
#   'humidity': 50,
#   'cloud': 0,
#   'feelslike_c': -7.5,
#   'feelslike_f': 18.5,
#   'windchill_c': -9.1,
#   'windchill_f': 15.5,
#   'heatindex_c': -3.9,
#   'heatindex_f': 24.9,
#   'dewpoint_c': -11.2,
#   'dewpoint_f': 11.8,
#   'vis_km': 16.0,
#   'vis_miles': 9.0,
#   'uv': 1.8,
#   'gust_mph': 9.5,
#   'gust_kph': 15.3,
#   'short_rad': 253.08,
#   'diff_rad': 46.86,
#   'dni': 0.0,
#   'gti': 47.26}}

# %%
current = data['current']
location = data['location']
temp_f = current['temp_f']
wind_mph = current['wind_mph']
humidity = current['humidity']

# %%
temp_f
# Out:
# 27.0

# %% [markdown]
# ## Function

# %%
def get_weather(city):
    url = f"http://api.weatherapi.com/v1/current.json?key={key}&q={city}"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        current = data['current']
        location = data['location']
        temp_f = current['temp_f']
        wind_mph = current['wind_mph']
        humidity = current['humidity']
        
        print(f"Weather for {location['name']}, {location['region']}")
        print(f"Temperature: {current['temp_f']} F / {current['temp_c']} C")
        print(f"Condition: {current['condition']['text']}")
        print(f"Humidity: {current['humidity']}%")
        print(f"Wind Speed: {current['wind_mph']} mph")
        
    else:
        Print(f"Error fetching data. There is no weather for {city}: {response.status_code}")
        
              
              
print(get_weather("Louisville"))
# Out:
# Weather for Louisville, Kentucky
# Temperature: 27.0 F / -2.8 C
# Condition: Sunny
# Humidity: 50%
# Wind Speed: 8.3 mph
# None

# %%
get_weather("Las Vegas")
# Out:
# Weather for Las Vegas, Nevada
# Temperature: 50.2 F / 10.1 C
# Condition: Sunny
# Humidity: 32%
# Wind Speed: 2.2 mph

# %%
get_weather("lulu")
# Out:
# Weather for Lulu, Shanghai
# Temperature: 44.6 F / 7.0 C
# Condition: Partly cloudy
# Humidity: 70%
# Wind Speed: 7.2 mph

# %%
cities = ['Kapaa', 'Lexington', 'Lihue', 'San Fransisco', 'Las Vegas']
weather_data = []

for city in cities:
    url = f"http://api.weatherapi.com/v1/current.json?key={key}&q={city}"
    response = requests.get(url)

    if response.status_code == 200:
        data = response.json()
        weather_data.append({
                "City": data['location']['name'],
                "Temperature": data['current']['temp_f'],
                "Condition": data['current']['condition']['text'],
                "Humidity": data['current']['humidity'],
                "Wind Speed": data['current']['wind_mph']})
    else:
        print("No weather today! Error.")

# %%
weather_data
# Out:
# [{'City': 'Kapaa',
#   'Temperature': 73.9,
#   'Condition': 'Patchy rain nearby',
#   'Humidity': 78,
#   'Wind Speed': 9.2},
#  {'City': 'Lexington-Fayette',
#   'Temperature': 27.0,
#   'Condition': 'Sunny',
#   'Humidity': 53,
#   'Wind Speed': 12.1},
#  {'City': 'Lihue',
#   'Temperature': 73.9,
#   'Condition': 'Patchy rain nearby',
#   'Humidity': 78,
#   'Wind Speed': 9.2},
#  {'City': 'San Marino',
#   'Temperature': 37.6,
#   'Condition': 'Light rain',
#   'Humidity': 93,
#   'Wind Speed': 15.7},
#  {'City': 'Las Vegas',
#   'Temperature': 50.2,
#   'Condition': 'Sunny',
#   'Humidity': 32,
#   'Wind Speed': 2.2}]

# %%
weather_df = pd.DataFrame(weather_data)

# %%
weather_df.head()
# Out:
#                 City  Temperature           Condition  Humidity  Wind Speed
# 0              Kapaa         73.9  Patchy rain nearby        78         9.2
# 1  Lexington-Fayette         27.0               Sunny        53        12.1
# 2              Lihue         73.9  Patchy rain nearby        78         9.2
# 3         San Marino         37.6          Light rain        93        15.7
# 4          Las Vegas         50.2               Sunny        32         2.2

# %%
weather_df.to_csv("sample_weather_data", index=False)

# %% [markdown]
# ## Video 2

# %%
from datetime import datetime

# %%
api_key = "<KEY HERE>"
baseurl = "http://api.weatherapi.com/v1"
# url = f"http://api.weatherapi.com/v1/current.json?key={key}&q={city}"
city = "louisville"

# %%
response = requests.get("http://api.weatherapi.com/v1/current.json?key={api_key}&q={city}")
response.status_code
# Out:
# 401

# %%
data = response.json()
data
# Out:
# {'error': {'code': 2006, 'message': 'API key is invalid.'}}
