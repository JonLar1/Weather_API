# %% [markdown]
# # Weather API

# %% [markdown]
# ## Package import

# %%
import pandas as pd
import requests

# %% [markdown]
# ## API Info

# %%
key = "<REDACTED_API_KEY>"
# baseurl = http://api.weatherapi.com/v1

# %% [markdown]
# ## Work

# %%
city = "louisville"
baseurl = f"http://api.weatherapi.com/v1/current.json?key={key}&q={city}"
response = requests.get(baseurl)

# %%
response.status_code
# Out:
# 200

# %%
data = response.json()
data
# Out:
# {'location': {'name': 'Louisville',
#   'region': 'Kentucky',
#   'country': 'United States of America',
#   'lat': 38.2542,
#   'lon': -85.7594,
#   'tz_id': 'America/Kentucky/Louisville',
#   'localtime_epoch': 1767188563,
#   'localtime': '2025-12-31 08:42'},
#  'current': {'last_updated_epoch': 1767187800,
#   'last_updated': '2025-12-31 08:30',
#   'temp_c': -0.6,
#   'temp_f': 30.9,
#   'is_day': 1,
#   'condition': {'text': 'Overcast',
#    'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#    'code': 1009},
#   'wind_mph': 8.5,
#   'wind_kph': 13.7,
#   'wind_degree': 246,
#   'wind_dir': 'WSW',
#   'pressure_mb': 1017.0,
#   'pressure_in': 30.03,
#   'precip_mm': 0.0,
#   'precip_in': 0.0,
#   'humidity': 61,
#   'cloud': 100,
#   'feelslike_c': -4.9,
#   'feelslike_f': 23.2,
#   'windchill_c': -3.7,
#   'windchill_f': 25.3,
#   'heatindex_c': -0.3,
#   'heatindex_f': 31.5,
#   'dewpoint_c': -3.7,
#   'dewpoint_f': 25.3,
#   'vis_km': 16.0,
#   'vis_miles': 9.0,
#   'uv': 0.0,
#   'gust_mph': 12.3,
#   'gust_kph': 19.8,
#   'short_rad': 0.0,
#   'diff_rad': 0.0,
#   'dni': 0.0,
#   'gti': 0.0}}

# %%
current = data['current']
location = data['location']
temp_f = current['temp_f']
wind_mph = current['wind_mph']
humidity = current['humidity']

# %%
temp_f
# Out:
# 30.9

# %% [markdown]
# ## Function

# %%
def get_weather(city):
    url = f"http://api.weatherapi.com/v1/current.json?key={key}&q={city}"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        current = data['current']
        location = data['location']
        temp_f = current['temp_f']
        wind_mph = current['wind_mph']
        humidity = current['humidity']
        
        print(f"Weather for {location['name']}, {location['region']}")
        print(f"Temperature: {current['temp_f']} F / {current['temp_c']} C")
        print(f"Condition: {current['condition']['text']}")
        print(f"Humidity: {current['humidity']}%")
        print(f"Wind Speed: {current['wind_mph']} mph")
        
    else:
        Print(f"Error fetching data. There is no weather for {city}: {response.status_code}")
        
              
              
print(get_weather("Louisville"))
# Out:
# Weather for Louisville, Kentucky
# Temperature: 30.9 F / -0.6 C
# Condition: Overcast
# Humidity: 61%
# Wind Speed: 8.5 mph
# None

# %%
get_weather("Las Vegas")
# Out:
# Weather for Las Vegas, Nevada
# Temperature: 42.1 F / 5.6 C
# Condition: Clear
# Humidity: 55%
# Wind Speed: 2.2 mph

# %%
get_weather("lulu")
# Out:
# Weather for Lulu, Shanghai
# Temperature: 44.8 F / 7.1 C
# Condition: Partly cloudy
# Humidity: 57%
# Wind Speed: 15.7 mph

# %%
cities = ['Kapaa', 'Lexington', 'Lihue', 'San Fransisco', 'Las Vegas']
weather_data = []

for city in cities:
    url = f"http://api.weatherapi.com/v1/current.json?key={key}&q={city}"
    response = requests.get(url)

    if response.status_code == 200:
        data = response.json()
        weather_data.append({
                "City": data['location']['name'],
                "Temperature": data['current']['temp_f'],
                "Condition": data['current']['condition']['text'],
                "Humidity": data['current']['humidity'],
                "Wind Speed": data['current']['wind_mph']})
    else:
        print("No weather today! Error.")

# %%
weather_data
# Out:
# [{'City': 'Kapaa',
#   'Temperature': 75.4,
#   'Condition': 'Partly cloudy',
#   'Humidity': 74,
#   'Wind Speed': 11.2},
#  {'City': 'Lexington-Fayette',
#   'Temperature': 28.9,
#   'Condition': 'Overcast',
#   'Humidity': 61,
#   'Wind Speed': 13.9},
#  {'City': 'Lihue',
#   'Temperature': 75.4,
#   'Condition': 'Partly cloudy',
#   'Humidity': 74,
#   'Wind Speed': 11.2},
#  {'City': 'San Marino',
#   'Temperature': 45.0,
#   'Condition': 'Patchy rain nearby',
#   'Humidity': 57,
#   'Wind Speed': 8.1},
#  {'City': 'Las Vegas',
#   'Temperature': 42.1,
#   'Condition': 'Clear',
#   'Humidity': 55,
#   'Wind Speed': 2.2}]

# %%
weather_df = pd.DataFrame(weather_data)

# %%
weather_df.head()
# Out:
#                 City  Temperature           Condition  Humidity  Wind Speed
# 0              Kapaa         75.4       Partly cloudy        74        11.2
# 1  Lexington-Fayette         28.9            Overcast        61        13.9
# 2              Lihue         75.4       Partly cloudy        74        11.2
# 3         San Marino         45.0  Patchy rain nearby        57         8.1
# 4          Las Vegas         42.1               Clear        55         2.2

# %%
weather_df.to_csv("sample_weather_data", index=False)

# %% [markdown]
# ## Video 2

# %%
from datetime import datetime

# %%
api_key = "<REDACTED_API_KEY>"
baseurl = "http://api.weatherapi.com/v1/"
# url = f"http://api.weatherapi.com/v1/current.json?key={key}&q={city}"
city = "louisville"

# %%
response = requests.get(f"http://api.weatherapi.com/v1/current.json?key={api_key}&q={city}")
response.status_code
# Out:
# 200

# %%
data = response.json()
data['current']
# Out:
# {'last_updated_epoch': 1767187800,
#  'last_updated': '2025-12-31 08:30',
#  'temp_c': -0.6,
#  'temp_f': 30.9,
#  'is_day': 1,
#  'condition': {'text': 'Overcast',
#   'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#   'code': 1009},
#  'wind_mph': 8.5,
#  'wind_kph': 13.7,
#  'wind_degree': 246,
#  'wind_dir': 'WSW',
#  'pressure_mb': 1017.0,
#  'pressure_in': 30.03,
#  'precip_mm': 0.0,
#  'precip_in': 0.0,
#  'humidity': 61,
#  'cloud': 100,
#  'feelslike_c': -4.9,
#  'feelslike_f': 23.2,
#  'windchill_c': -3.7,
#  'windchill_f': 25.3,
#  'heatindex_c': -0.3,
#  'heatindex_f': 31.5,
#  'dewpoint_c': -3.7,
#  'dewpoint_f': 25.3,
#  'vis_km': 16.0,
#  'vis_miles': 9.0,
#  'uv': 0.0,
#  'gust_mph': 12.3,
#  'gust_kph': 19.8,
#  'short_rad': 0.0,
#  'diff_rad': 0.0,
#  'dni': 0.0,
#  'gti': 0.0}

# %%
forecast_url = f"{baseurl}forecast.json?key={api_key}&q={city}&days=3"
forecast_response = requests.get(forecast_url)
forecast_response.status_code
# Out:
# 200

# %%
forecast_response.json()
# Out:
# {'location': {'name': 'Louisville',
#   'region': 'Kentucky',
#   'country': 'United States of America',
#   'lat': 38.2542,
#   'lon': -85.7594,
#   'tz_id': 'America/Kentucky/Louisville',
#   'localtime_epoch': 1767188521,
#   'localtime': '2025-12-31 08:42'},
#  'current': {'last_updated_epoch': 1767187800,
#   'last_updated': '2025-12-31 08:30',
#   'temp_c': -0.6,
#   'temp_f': 30.9,
#   'is_day': 1,
#   'condition': {'text': 'Overcast',
#    'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#    'code': 1009},
#   'wind_mph': 8.5,
#   'wind_kph': 13.7,
#   'wind_degree': 246,
#   'wind_dir': 'WSW',
#   'pressure_mb': 1017.0,
#   'pressure_in': 30.03,
#   'precip_mm': 0.0,
#   'precip_in': 0.0,
#   'humidity': 61,
#   'cloud': 100,
#   'feelslike_c': -4.9,
#   'feelslike_f': 23.2,
#   'windchill_c': -3.7,
#   'windchill_f': 25.3,
#   'heatindex_c': -0.3,
#   'heatindex_f': 31.5,
#   'dewpoint_c': -3.7,
#   'dewpoint_f': 25.3,
#   'vis_km': 16.0,
#   'vis_miles': 9.0,
#   'uv': 0.0,
#   'gust_mph': 12.3,
#   'gust_kph': 19.8,
#   'short_rad': 0.0,
#   'diff_rad': 0.0,
#   'dni': 0.0,
#   'gti': 0.0},
#  'forecast': {'forecastday': [{'date': '2025-12-31',
#     'date_epoch': 1767139200,
#     'day': {'maxtemp_c': 2.9,
#      'maxtemp_f': 37.2,
#      'mintemp_c': -0.6,
#      'mintemp_f': 30.9,
#      'avgtemp_c': 0.9,
#      'avgtemp_f': 33.7,
#      'maxwind_mph': 10.5,
#      'maxwind_kph': 16.9,
#      'totalprecip_mm': 0.0,
#      'totalprecip_in': 0.0,
#      'totalsnow_cm': 0.0,
#      'avgvis_km': 10.0,
#      'avgvis_miles': 6.0,
#      'avghumidity': 77,
#      'daily_will_it_rain': 0,
#      'daily_chance_of_rain': 0,
#      'daily_will_it_snow': 0,
#      'daily_chance_of_snow': 0,
#      'condition': {'text': 'Overcast ',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#       'code': 1009},
#      'uv': 0.3},
#     'astro': {'sunrise': '08:00 AM',
#      'sunset': '05:33 PM',
#      'moonrise': '02:36 PM',
#      'moonset': '05:05 AM',
#      'moon_phase': 'Waxing Gibbous',
#      'moon_illumination': 84,
#      'is_moon_up': 1,
#      'is_sun_up': 0},
#     'hour': [{'time_epoch': 1767157200,
#       'time': '2025-12-31 00:00',
#       'temp_c': -0.6,
#       'temp_f': 30.9,
#       'is_day': 0,
#       'condition': {'text': 'Clear ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 8.5,
#       'wind_kph': 13.7,
#       'wind_degree': 240,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1020.0,
#       'pressure_in': 30.12,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 68,
#       'cloud': 0,
#       'feelslike_c': -4.5,
#       'feelslike_f': 23.9,
#       'windchill_c': -4.5,
#       'windchill_f': 23.9,
#       'heatindex_c': -0.6,
#       'heatindex_f': 30.9,
#       'dewpoint_c': -5.7,
#       'dewpoint_f': 21.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 12.1,
#       'gust_kph': 19.5,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1767160800,
#       'time': '2025-12-31 01:00',
#       'temp_c': -0.5,
#       'temp_f': 31.0,
#       'is_day': 0,
#       'condition': {'text': 'Clear ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 8.9,
#       'wind_kph': 14.4,
#       'wind_degree': 238,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1019.0,
#       'pressure_in': 30.09,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 67,
#       'cloud': 0,
#       'feelslike_c': -4.2,
#       'feelslike_f': 24.4,
#       'windchill_c': -4.2,
#       'windchill_f': 24.4,
#       'heatindex_c': -0.5,
#       'heatindex_f': 31.0,
#       'dewpoint_c': -5.8,
#       'dewpoint_f': 21.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 12.7,
#       'gust_kph': 20.5,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1767164400,
#       'time': '2025-12-31 02:00',
#       'temp_c': -0.5,
#       'temp_f': 31.2,
#       'is_day': 0,
#       'condition': {'text': 'Clear ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 8.9,
#       'wind_kph': 14.4,
#       'wind_degree': 234,
#       'wind_dir': 'SW',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.06,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 68,
#       'cloud': 0,
#       'feelslike_c': -4.2,
#       'feelslike_f': 24.5,
#       'windchill_c': -4.2,
#       'windchill_f': 24.5,
#       'heatindex_c': -0.5,
#       'heatindex_f': 31.2,
#       'dewpoint_c': -5.7,
#       'dewpoint_f': 21.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 12.7,
#       'gust_kph': 20.5,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1767168000,
#       'time': '2025-12-31 03:00',
#       'temp_c': -0.4,
#       'temp_f': 31.3,
#       'is_day': 0,
#       'condition': {'text': 'Clear ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 9.2,
#       'wind_kph': 14.8,
#       'wind_degree': 237,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.04,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 68,
#       'cloud': 0,
#       'feelslike_c': -4.4,
#       'feelslike_f': 24.1,
#       'windchill_c': -4.4,
#       'windchill_f': 24.1,
#       'heatindex_c': -0.4,
#       'heatindex_f': 31.3,
#       'dewpoint_c': -5.5,
#       'dewpoint_f': 22.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 13.2,
#       'gust_kph': 21.3,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1767171600,
#       'time': '2025-12-31 04:00',
#       'temp_c': -0.3,
#       'temp_f': 31.4,
#       'is_day': 0,
#       'condition': {'text': 'Clear ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 9.8,
#       'wind_kph': 15.8,
#       'wind_degree': 234,
#       'wind_dir': 'SW',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.02,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 70,
#       'cloud': 0,
#       'feelslike_c': -4.6,
#       'feelslike_f': 23.8,
#       'windchill_c': -4.6,
#       'windchill_f': 23.8,
#       'heatindex_c': -0.3,
#       'heatindex_f': 31.4,
#       'dewpoint_c': -5.1,
#       'dewpoint_f': 22.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 14.1,
#       'gust_kph': 22.7,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1767175200,
#       'time': '2025-12-31 05:00',
#       'temp_c': -0.3,
#       'temp_f': 31.4,
#       'is_day': 0,
#       'condition': {'text': 'Clear ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 10.5,
#       'wind_kph': 16.9,
#       'wind_degree': 235,
#       'wind_dir': 'SW',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.01,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 71,
#       'cloud': 0,
#       'feelslike_c': -4.2,
#       'feelslike_f': 24.5,
#       'windchill_c': -4.2,
#       'windchill_f': 24.5,
#       'heatindex_c': -0.3,
#       'heatindex_f': 31.4,
#       'dewpoint_c': -5.0,
#       'dewpoint_f': 23.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 15.3,
#       'gust_kph': 24.7,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1767178800,
#       'time': '2025-12-31 06:00',
#       'temp_c': -0.3,
#       'temp_f': 31.4,
#       'is_day': 0,
#       'condition': {'text': 'Clear ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 9.8,
#       'wind_kph': 15.8,
#       'wind_degree': 242,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.01,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 75,
#       'cloud': 0,
#       'feelslike_c': -3.9,
#       'feelslike_f': 24.9,
#       'windchill_c': -3.9,
#       'windchill_f': 24.9,
#       'heatindex_c': -0.3,
#       'heatindex_f': 31.4,
#       'dewpoint_c': -4.2,
#       'dewpoint_f': 24.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 14.4,
#       'gust_kph': 23.2,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1767182400,
#       'time': '2025-12-31 07:00',
#       'temp_c': -0.3,
#       'temp_f': 31.5,
#       'is_day': 0,
#       'condition': {'text': 'Clear ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 8.9,
#       'wind_kph': 14.4,
#       'wind_degree': 245,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.02,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 76,
#       'cloud': 0,
#       'feelslike_c': -3.8,
#       'feelslike_f': 25.2,
#       'windchill_c': -3.8,
#       'windchill_f': 25.2,
#       'heatindex_c': -0.3,
#       'heatindex_f': 31.5,
#       'dewpoint_c': -3.9,
#       'dewpoint_f': 24.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 13.0,
#       'gust_kph': 20.8,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1767186000,
#       'time': '2025-12-31 08:00',
#       'temp_c': -0.6,
#       'temp_f': 30.9,
#       'is_day': 1,
#       'condition': {'text': 'Overcast',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#        'code': 1009},
#       'wind_mph': 8.5,
#       'wind_kph': 13.7,
#       'wind_degree': 246,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.03,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 61,
#       'cloud': 100,
#       'feelslike_c': -3.7,
#       'feelslike_f': 25.3,
#       'windchill_c': -3.7,
#       'windchill_f': 25.3,
#       'heatindex_c': -0.3,
#       'heatindex_f': 31.5,
#       'dewpoint_c': -3.7,
#       'dewpoint_f': 25.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 16.0,
#       'vis_miles': 9.0,
#       'gust_mph': 12.3,
#       'gust_kph': 19.8,
#       'uv': 0.0,
#       'short_rad': 0.0,
#       'diff_rad': 0.0,
#       'dni': 0.0,
#       'gti': 0.0},
#      {'time_epoch': 1767189600,
#       'time': '2025-12-31 09:00',
#       'temp_c': -0.1,
#       'temp_f': 31.9,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 7.8,
#       'wind_kph': 12.6,
#       'wind_degree': 252,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.02,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 78,
#       'cloud': 0,
#       'feelslike_c': -3.7,
#       'feelslike_f': 25.3,
#       'windchill_c': -3.7,
#       'windchill_f': 25.3,
#       'heatindex_c': -0.1,
#       'heatindex_f': 31.9,
#       'dewpoint_c': -3.6,
#       'dewpoint_f': 25.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.1,
#       'gust_kph': 17.9,
#       'uv': 0.2,
#       'short_rad': 15.12,
#       'diff_rad': 7.07,
#       'dni': 18.17,
#       'gti': 3.42},
#      {'time_epoch': 1767193200,
#       'time': '2025-12-31 10:00',
#       'temp_c': 0.5,
#       'temp_f': 32.8,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 7.8,
#       'wind_kph': 12.6,
#       'wind_degree': 250,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.03,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 78,
#       'cloud': 8,
#       'feelslike_c': -3.5,
#       'feelslike_f': 25.7,
#       'windchill_c': -3.5,
#       'windchill_f': 25.7,
#       'heatindex_c': 0.5,
#       'heatindex_f': 32.8,
#       'dewpoint_c': -3.2,
#       'dewpoint_f': 26.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.3,
#       'gust_kph': 16.5,
#       'uv': 0.6,
#       'short_rad': 51.22,
#       'diff_rad': 24.1,
#       'dni': 75.22,
#       'gti': 7.45},
#      {'time_epoch': 1767196800,
#       'time': '2025-12-31 11:00',
#       'temp_c': 1.2,
#       'temp_f': 34.1,
#       'is_day': 1,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#        'code': 1009},
#       'wind_mph': 8.5,
#       'wind_kph': 13.7,
#       'wind_degree': 262,
#       'wind_dir': 'W',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.04,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 78,
#       'cloud': 100,
#       'feelslike_c': -2.8,
#       'feelslike_f': 27.0,
#       'windchill_c': -2.8,
#       'windchill_f': 27.0,
#       'heatindex_c': 1.2,
#       'heatindex_f': 34.1,
#       'dewpoint_c': -2.3,
#       'dewpoint_f': 27.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.7,
#       'gust_kph': 17.2,
#       'uv': 1.0,
#       'short_rad': 88.12,
#       'diff_rad': 42.5,
#       'dni': 192.51,
#       'gti': 0.0},
#      {'time_epoch': 1767200400,
#       'time': '2025-12-31 12:00',
#       'temp_c': 1.9,
#       'temp_f': 35.5,
#       'is_day': 1,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#        'code': 1009},
#       'wind_mph': 8.3,
#       'wind_kph': 13.3,
#       'wind_degree': 263,
#       'wind_dir': 'W',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.02,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 80,
#       'cloud': 100,
#       'feelslike_c': -2.0,
#       'feelslike_f': 28.4,
#       'windchill_c': -2.0,
#       'windchill_f': 28.4,
#       'heatindex_c': 1.9,
#       'heatindex_f': 35.5,
#       'dewpoint_c': -1.2,
#       'dewpoint_f': 29.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.1,
#       'gust_kph': 16.3,
#       'uv': 1.4,
#       'short_rad': 129.14,
#       'diff_rad': 62.61,
#       'dni': 823.81,
#       'gti': 0.0},
#      {'time_epoch': 1767204000,
#       'time': '2025-12-31 13:00',
#       'temp_c': 2.4,
#       'temp_f': 36.4,
#       'is_day': 1,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#        'code': 1009},
#       'wind_mph': 8.5,
#       'wind_kph': 13.7,
#       'wind_degree': 258,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.0,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 81,
#       'cloud': 100,
#       'feelslike_c': -1.5,
#       'feelslike_f': 29.4,
#       'windchill_c': -1.5,
#       'windchill_f': 29.4,
#       'heatindex_c': 2.4,
#       'heatindex_f': 36.4,
#       'dewpoint_c': -0.2,
#       'dewpoint_f': 31.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.2,
#       'gust_kph': 16.5,
#       'uv': 1.5,
#       'short_rad': 161.9,
#       'diff_rad': 78.08,
#       'dni': 0.0,
#       'gti': 73.17},
#      {'time_epoch': 1767207600,
#       'time': '2025-12-31 14:00',
#       'temp_c': 2.6,
#       'temp_f': 36.7,
#       'is_day': 1,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#        'code': 1009},
#       'wind_mph': 9.2,
#       'wind_kph': 14.8,
#       'wind_degree': 258,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.96,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 80,
#       'cloud': 100,
#       'feelslike_c': -1.0,
#       'feelslike_f': 30.2,
#       'windchill_c': -1.0,
#       'windchill_f': 30.2,
#       'heatindex_c': 2.6,
#       'heatindex_f': 36.7,
#       'dewpoint_c': -0.2,
#       'dewpoint_f': 31.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.2,
#       'gust_kph': 18.0,
#       'uv': 1.5,
#       'short_rad': 304.84,
#       'diff_rad': 150.43,
#       'dni': 0.0,
#       'gti': 140.83},
#      {'time_epoch': 1767211200,
#       'time': '2025-12-31 15:00',
#       'temp_c': 2.7,
#       'temp_f': 36.9,
#       'is_day': 1,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#        'code': 1009},
#       'wind_mph': 8.9,
#       'wind_kph': 14.4,
#       'wind_degree': 261,
#       'wind_dir': 'W',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.96,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 82,
#       'cloud': 100,
#       'feelslike_c': -0.8,
#       'feelslike_f': 30.5,
#       'windchill_c': -0.8,
#       'windchill_f': 30.5,
#       'heatindex_c': 2.7,
#       'heatindex_f': 36.9,
#       'dewpoint_c': 0.0,
#       'dewpoint_f': 32.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.2,
#       'gust_kph': 18.0,
#       'uv': 0.8,
#       'short_rad': 285.42,
#       'diff_rad': 139.55,
#       'dni': 0.0,
#       'gti': 130.7},
#      {'time_epoch': 1767214800,
#       'time': '2025-12-31 16:00',
#       'temp_c': 2.8,
#       'temp_f': 37.0,
#       'is_day': 1,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#        'code': 1009},
#       'wind_mph': 9.2,
#       'wind_kph': 14.8,
#       'wind_degree': 248,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.93,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 83,
#       'cloud': 100,
#       'feelslike_c': -0.6,
#       'feelslike_f': 30.8,
#       'windchill_c': -0.6,
#       'windchill_f': 30.8,
#       'heatindex_c': 2.8,
#       'heatindex_f': 37.0,
#       'dewpoint_c': 0.3,
#       'dewpoint_f': 32.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 12.1,
#       'gust_kph': 19.4,
#       'uv': 0.4,
#       'short_rad': 253.98,
#       'diff_rad': 123.62,
#       'dni': 0.0,
#       'gti': 115.8},
#      {'time_epoch': 1767218400,
#       'time': '2025-12-31 17:00',
#       'temp_c': 2.8,
#       'temp_f': 37.0,
#       'is_day': 1,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#        'code': 1009},
#       'wind_mph': 9.2,
#       'wind_kph': 14.8,
#       'wind_degree': 255,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1013.0,
#       'pressure_in': 29.93,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 83,
#       'cloud': 100,
#       'feelslike_c': -0.5,
#       'feelslike_f': 31.1,
#       'windchill_c': -0.5,
#       'windchill_f': 31.1,
#       'heatindex_c': 2.8,
#       'heatindex_f': 37.0,
#       'dewpoint_c': 0.4,
#       'dewpoint_f': 32.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 12.6,
#       'gust_kph': 20.3,
#       'uv': 0.0,
#       'short_rad': 211.7,
#       'diff_rad': 103.03,
#       'dni': 0.0,
#       'gti': 96.52},
#      {'time_epoch': 1767222000,
#       'time': '2025-12-31 18:00',
#       'temp_c': 1.9,
#       'temp_f': 35.3,
#       'is_day': 0,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#        'code': 1009},
#       'wind_mph': 9.2,
#       'wind_kph': 14.8,
#       'wind_degree': 254,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.94,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 85,
#       'cloud': 100,
#       'feelslike_c': -2.0,
#       'feelslike_f': 28.4,
#       'windchill_c': -2.0,
#       'windchill_f': 28.4,
#       'heatindex_c': 1.9,
#       'heatindex_f': 35.3,
#       'dewpoint_c': 0.5,
#       'dewpoint_f': 32.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 13.7,
#       'gust_kph': 22.0,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1767225600,
#       'time': '2025-12-31 19:00',
#       'temp_c': 1.7,
#       'temp_f': 35.0,
#       'is_day': 0,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 8.3,
#       'wind_kph': 13.3,
#       'wind_degree': 255,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.95,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 78,
#       'cloud': 38,
#       'feelslike_c': -2.5,
#       'feelslike_f': 27.5,
#       'windchill_c': -2.5,
#       'windchill_f': 27.5,
#       'heatindex_c': 1.7,
#       'heatindex_f': 35.0,
#       'dewpoint_c': -2.5,
#       'dewpoint_f': 27.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 13.1,
#       'gust_kph': 21.1,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1767229200,
#       'time': '2025-12-31 20:00',
#       'temp_c': 1.7,
#       'temp_f': 35.0,
#       'is_day': 0,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 8.5,
#       'wind_kph': 13.7,
#       'wind_degree': 248,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.96,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 79,
#       'cloud': 59,
#       'feelslike_c': -2.7,
#       'feelslike_f': 27.2,
#       'windchill_c': -2.7,
#       'windchill_f': 27.2,
#       'heatindex_c': 1.7,
#       'heatindex_f': 35.0,
#       'dewpoint_c': -1.7,
#       'dewpoint_f': 29.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 13.3,
#       'gust_kph': 21.4,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1767232800,
#       'time': '2025-12-31 21:00',
#       'temp_c': 1.7,
#       'temp_f': 35.0,
#       'is_day': 0,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 9.2,
#       'wind_kph': 14.8,
#       'wind_degree': 253,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.97,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 81,
#       'cloud': 79,
#       'feelslike_c': -2.7,
#       'feelslike_f': 27.1,
#       'windchill_c': -2.7,
#       'windchill_f': 27.1,
#       'heatindex_c': 1.7,
#       'heatindex_f': 35.0,
#       'dewpoint_c': -1.2,
#       'dewpoint_f': 29.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 13.9,
#       'gust_kph': 22.4,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1767236400,
#       'time': '2025-12-31 22:00',
#       'temp_c': 1.1,
#       'temp_f': 33.9,
#       'is_day': 0,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 8.9,
#       'wind_kph': 14.4,
#       'wind_degree': 256,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.97,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 82,
#       'cloud': 90,
#       'feelslike_c': -3.2,
#       'feelslike_f': 26.2,
#       'windchill_c': -3.2,
#       'windchill_f': 26.2,
#       'heatindex_c': 1.1,
#       'heatindex_f': 33.9,
#       'dewpoint_c': -1.0,
#       'dewpoint_f': 30.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 13.4,
#       'gust_kph': 21.6,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1767240000,
#       'time': '2025-12-31 23:00',
#       'temp_c': 1.2,
#       'temp_f': 34.2,
#       'is_day': 0,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 8.7,
#       'wind_kph': 14.0,
#       'wind_degree': 256,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.97,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 78,
#       'cloud': 49,
#       'feelslike_c': -3.1,
#       'feelslike_f': 26.5,
#       'windchill_c': -3.1,
#       'windchill_f': 26.5,
#       'heatindex_c': 1.2,
#       'heatindex_f': 34.2,
#       'dewpoint_c': -2.8,
#       'dewpoint_f': 26.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 13.6,
#       'gust_kph': 21.8,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0}]},
#    {'date': '2026-01-01',
#     'date_epoch': 1767225600,
#     'day': {'maxtemp_c': 2.6,
#      'maxtemp_f': 36.7,
#      'mintemp_c': 0.3,
#      'mintemp_f': 32.5,
#      'avgtemp_c': 1.3,
#      'avgtemp_f': 34.3,
#      'maxwind_mph': 8.7,
#      'maxwind_kph': 14.0,
#      'totalprecip_mm': 0.0,
#      'totalprecip_in': 0.0,
#      'totalsnow_cm': 0.0,
#      'avgvis_km': 10.0,
#      'avgvis_miles': 6.0,
#      'avghumidity': 84,
#      'daily_will_it_rain': 0,
#      'daily_chance_of_rain': 0,
#      'daily_will_it_snow': 0,
#      'daily_chance_of_snow': 0,
#      'condition': {'text': 'Cloudy ',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#       'code': 1006},
#      'uv': 0.4},
#     'astro': {'sunrise': '08:00 AM',
#      'sunset': '05:34 PM',
#      'moonrise': '03:32 PM',
#      'moonset': '06:21 AM',
#      'moon_phase': 'Waxing Gibbous',
#      'moon_illumination': 91,
#      'is_moon_up': 1,
#      'is_sun_up': 0},
#     'hour': [{'time_epoch': 1767243600,
#       'time': '2026-01-01 00:00',
#       'temp_c': 1.2,
#       'temp_f': 34.2,
#       'is_day': 0,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#        'code': 1009},
#       'wind_mph': 8.7,
#       'wind_kph': 14.0,
#       'wind_degree': 255,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.97,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 84,
#       'cloud': 100,
#       'feelslike_c': -3.0,
#       'feelslike_f': 26.6,
#       'windchill_c': -3.0,
#       'windchill_f': 26.6,
#       'heatindex_c': 1.2,
#       'heatindex_f': 34.2,
#       'dewpoint_c': -1.0,
#       'dewpoint_f': 30.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 13.6,
#       'gust_kph': 22.0,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1767247200,
#       'time': '2026-01-01 01:00',
#       'temp_c': 1.1,
#       'temp_f': 34.0,
#       'is_day': 0,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#        'code': 1009},
#       'wind_mph': 8.5,
#       'wind_kph': 13.7,
#       'wind_degree': 264,
#       'wind_dir': 'W',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.97,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 84,
#       'cloud': 100,
#       'feelslike_c': -3.0,
#       'feelslike_f': 26.5,
#       'windchill_c': -3.0,
#       'windchill_f': 26.5,
#       'heatindex_c': 1.1,
#       'heatindex_f': 34.0,
#       'dewpoint_c': -1.1,
#       'dewpoint_f': 29.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 13.1,
#       'gust_kph': 21.1,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1767250800,
#       'time': '2026-01-01 02:00',
#       'temp_c': 1.0,
#       'temp_f': 33.8,
#       'is_day': 0,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#        'code': 1009},
#       'wind_mph': 7.8,
#       'wind_kph': 12.6,
#       'wind_degree': 272,
#       'wind_dir': 'W',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.97,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 85,
#       'cloud': 100,
#       'feelslike_c': -3.0,
#       'feelslike_f': 26.7,
#       'windchill_c': -3.0,
#       'windchill_f': 26.7,
#       'heatindex_c': 1.0,
#       'heatindex_f': 33.8,
#       'dewpoint_c': -1.3,
#       'dewpoint_f': 29.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.1,
#       'gust_kph': 17.8,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1767254400,
#       'time': '2026-01-01 03:00',
#       'temp_c': 0.9,
#       'temp_f': 33.6,
#       'is_day': 0,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#        'code': 1009},
#       'wind_mph': 6.7,
#       'wind_kph': 10.8,
#       'wind_degree': 276,
#       'wind_dir': 'W',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.98,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 87,
#       'cloud': 100,
#       'feelslike_c': -2.9,
#       'feelslike_f': 26.8,
#       'windchill_c': -2.9,
#       'windchill_f': 26.8,
#       'heatindex_c': 0.9,
#       'heatindex_f': 33.6,
#       'dewpoint_c': -1.1,
#       'dewpoint_f': 30.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 9.5,
#       'gust_kph': 15.2,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1767258000,
#       'time': '2026-01-01 04:00',
#       'temp_c': 0.8,
#       'temp_f': 33.4,
#       'is_day': 0,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#        'code': 1009},
#       'wind_mph': 6.3,
#       'wind_kph': 10.1,
#       'wind_degree': 278,
#       'wind_dir': 'W',
#       'pressure_mb': 1016.0,
#       'pressure_in': 29.99,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 88,
#       'cloud': 100,
#       'feelslike_c': -2.8,
#       'feelslike_f': 27.0,
#       'windchill_c': -2.8,
#       'windchill_f': 27.0,
#       'heatindex_c': 0.8,
#       'heatindex_f': 33.4,
#       'dewpoint_c': -1.0,
#       'dewpoint_f': 30.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 8.8,
#       'gust_kph': 14.1,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1767261600,
#       'time': '2026-01-01 05:00',
#       'temp_c': 0.7,
#       'temp_f': 33.2,
#       'is_day': 0,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#        'code': 1009},
#       'wind_mph': 5.4,
#       'wind_kph': 8.6,
#       'wind_degree': 307,
#       'wind_dir': 'NW',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.0,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 89,
#       'cloud': 100,
#       'feelslike_c': -2.6,
#       'feelslike_f': 27.4,
#       'windchill_c': -2.6,
#       'windchill_f': 27.4,
#       'heatindex_c': 0.7,
#       'heatindex_f': 33.2,
#       'dewpoint_c': -1.0,
#       'dewpoint_f': 30.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 7.3,
#       'gust_kph': 11.8,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1767265200,
#       'time': '2026-01-01 06:00',
#       'temp_c': 0.6,
#       'temp_f': 33.1,
#       'is_day': 0,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#        'code': 1009},
#       'wind_mph': 6.7,
#       'wind_kph': 10.8,
#       'wind_degree': 2,
#       'wind_dir': 'N',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.02,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 90,
#       'cloud': 92,
#       'feelslike_c': -2.4,
#       'feelslike_f': 27.7,
#       'windchill_c': -2.4,
#       'windchill_f': 27.7,
#       'heatindex_c': 0.6,
#       'heatindex_f': 33.1,
#       'dewpoint_c': -0.9,
#       'dewpoint_f': 30.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 8.8,
#       'gust_kph': 14.2,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1767268800,
#       'time': '2026-01-01 07:00',
#       'temp_c': 0.6,
#       'temp_f': 33.0,
#       'is_day': 0,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#        'code': 1009},
#       'wind_mph': 6.5,
#       'wind_kph': 10.4,
#       'wind_degree': 16,
#       'wind_dir': 'NNE',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.04,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 90,
#       'cloud': 88,
#       'feelslike_c': -2.2,
#       'feelslike_f': 28.1,
#       'windchill_c': -2.2,
#       'windchill_f': 28.1,
#       'heatindex_c': 0.6,
#       'heatindex_f': 33.0,
#       'dewpoint_c': -0.9,
#       'dewpoint_f': 30.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 8.2,
#       'gust_kph': 13.2,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1767272400,
#       'time': '2026-01-01 08:00',
#       'temp_c': 0.5,
#       'temp_f': 32.9,
#       'is_day': 0,
#       'condition': {'text': 'Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png',
#        'code': 1006},
#       'wind_mph': 5.4,
#       'wind_kph': 8.6,
#       'wind_degree': 351,
#       'wind_dir': 'N',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.05,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 91,
#       'cloud': 85,
#       'feelslike_c': -1.9,
#       'feelslike_f': 28.6,
#       'windchill_c': -1.9,
#       'windchill_f': 28.6,
#       'heatindex_c': 0.5,
#       'heatindex_f': 32.9,
#       'dewpoint_c': -0.8,
#       'dewpoint_f': 30.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 7.1,
#       'gust_kph': 11.5,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1767276000,
#       'time': '2026-01-01 09:00',
#       'temp_c': 0.4,
#       'temp_f': 32.7,
#       'is_day': 1,
#       'condition': {'text': 'Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#        'code': 1006},
#       'wind_mph': 5.4,
#       'wind_kph': 8.6,
#       'wind_degree': 351,
#       'wind_dir': 'N',
#       'pressure_mb': 1019.0,
#       'pressure_in': 30.08,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 91,
#       'cloud': 92,
#       'feelslike_c': -1.7,
#       'feelslike_f': 29.0,
#       'windchill_c': -1.7,
#       'windchill_f': 29.0,
#       'heatindex_c': 0.4,
#       'heatindex_f': 32.7,
#       'dewpoint_c': -1.0,
#       'dewpoint_f': 30.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 7.4,
#       'gust_kph': 11.9,
#       'uv': 0.2,
#       'short_rad': 20.38,
#       'diff_rad': 8.69,
#       'dni': 26.29,
#       'gti': 3.58},
#      {'time_epoch': 1767279600,
#       'time': '2026-01-01 10:00',
#       'temp_c': 0.4,
#       'temp_f': 32.6,
#       'is_day': 1,
#       'condition': {'text': 'Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#        'code': 1006},
#       'wind_mph': 4.0,
#       'wind_kph': 6.5,
#       'wind_degree': 19,
#       'wind_dir': 'NNE',
#       'pressure_mb': 1019.0,
#       'pressure_in': 30.09,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 90,
#       'cloud': 96,
#       'feelslike_c': -1.5,
#       'feelslike_f': 29.3,
#       'windchill_c': -1.5,
#       'windchill_f': 29.3,
#       'heatindex_c': 0.4,
#       'heatindex_f': 32.6,
#       'dewpoint_c': -1.0,
#       'dewpoint_f': 30.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.0,
#       'gust_kph': 8.0,
#       'uv': 0.8,
#       'short_rad': 76.6,
#       'diff_rad': 24.14,
#       'dni': 144.73,
#       'gti': 0.0},
#      {'time_epoch': 1767283200,
#       'time': '2026-01-01 11:00',
#       'temp_c': 0.6,
#       'temp_f': 33.1,
#       'is_day': 1,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#        'code': 1009},
#       'wind_mph': 3.8,
#       'wind_kph': 6.1,
#       'wind_degree': 18,
#       'wind_dir': 'NNE',
#       'pressure_mb': 1020.0,
#       'pressure_in': 30.11,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 90,
#       'cloud': 100,
#       'feelslike_c': -0.9,
#       'feelslike_f': 30.3,
#       'windchill_c': -0.9,
#       'windchill_f': 30.3,
#       'heatindex_c': 0.6,
#       'heatindex_f': 33.1,
#       'dewpoint_c': -1.1,
#       'dewpoint_f': 30.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.4,
#       'gust_kph': 7.1,
#       'uv': 1.4,
#       'short_rad': 140.1,
#       'diff_rad': 36.85,
#       'dni': 431.7,
#       'gti': 0.0},
#      {'time_epoch': 1767286800,
#       'time': '2026-01-01 12:00',
#       'temp_c': 0.9,
#       'temp_f': 33.6,
#       'is_day': 1,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#        'code': 1009},
#       'wind_mph': 3.1,
#       'wind_kph': 5.0,
#       'wind_degree': 8,
#       'wind_dir': 'N',
#       'pressure_mb': 1019.0,
#       'pressure_in': 30.09,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 86,
#       'cloud': 91,
#       'feelslike_c': -0.4,
#       'feelslike_f': 31.2,
#       'windchill_c': -0.4,
#       'windchill_f': 31.2,
#       'heatindex_c': 0.9,
#       'heatindex_f': 33.6,
#       'dewpoint_c': -1.2,
#       'dewpoint_f': 29.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 3.6,
#       'gust_kph': 5.8,
#       'uv': 2.0,
#       'short_rad': 198.18,
#       'diff_rad': 46.43,
#       'dni': 1825.95,
#       'gti': 0.0},
#      {'time_epoch': 1767290400,
#       'time': '2026-01-01 13:00',
#       'temp_c': 1.1,
#       'temp_f': 34.0,
#       'is_day': 1,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#        'code': 1009},
#       'wind_mph': 1.6,
#       'wind_kph': 2.5,
#       'wind_degree': 327,
#       'wind_dir': 'NNW',
#       'pressure_mb': 1019.0,
#       'pressure_in': 30.09,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 84,
#       'cloud': 86,
#       'feelslike_c': 0.0,
#       'feelslike_f': 32.1,
#       'windchill_c': 0.0,
#       'windchill_f': 32.1,
#       'heatindex_c': 1.1,
#       'heatindex_f': 34.0,
#       'dewpoint_c': -1.2,
#       'dewpoint_f': 29.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 1.8,
#       'gust_kph': 2.9,
#       'uv': 2.1,
#       'short_rad': 244.44,
#       'diff_rad': 53.43,
#       'dni': 0.0,
#       'gti': 52.94},
#      {'time_epoch': 1767294000,
#       'time': '2026-01-01 14:00',
#       'temp_c': 1.6,
#       'temp_f': 34.8,
#       'is_day': 1,
#       'condition': {'text': 'Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#        'code': 1006},
#       'wind_mph': 2.7,
#       'wind_kph': 4.3,
#       'wind_degree': 295,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1019.0,
#       'pressure_in': 30.08,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 82,
#       'cloud': 82,
#       'feelslike_c': 0.4,
#       'feelslike_f': 32.7,
#       'windchill_c': 0.4,
#       'windchill_f': 32.7,
#       'heatindex_c': 1.6,
#       'heatindex_f': 34.8,
#       'dewpoint_c': -1.3,
#       'dewpoint_f': 29.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 3.1,
#       'gust_kph': 5.0,
#       'uv': 1.7,
#       'short_rad': 461.32,
#       'diff_rad': 86.91,
#       'dni': 0.0,
#       'gti': 87.49},
#      {'time_epoch': 1767297600,
#       'time': '2026-01-01 15:00',
#       'temp_c': 1.9,
#       'temp_f': 35.5,
#       'is_day': 1,
#       'condition': {'text': 'Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#        'code': 1006},
#       'wind_mph': 2.9,
#       'wind_kph': 4.7,
#       'wind_degree': 281,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.07,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 78,
#       'cloud': 75,
#       'feelslike_c': 0.6,
#       'feelslike_f': 33.1,
#       'windchill_c': 0.6,
#       'windchill_f': 33.1,
#       'heatindex_c': 1.9,
#       'heatindex_f': 35.5,
#       'dewpoint_c': -1.4,
#       'dewpoint_f': 29.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 3.4,
#       'gust_kph': 5.4,
#       'uv': 1.1,
#       'short_rad': 425.72,
#       'diff_rad': 83.74,
#       'dni': 0.0,
#       'gti': 83.89},
#      {'time_epoch': 1767301200,
#       'time': '2026-01-01 16:00',
#       'temp_c': 2.3,
#       'temp_f': 36.1,
#       'is_day': 1,
#       'condition': {'text': 'Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#        'code': 1006},
#       'wind_mph': 2.9,
#       'wind_kph': 4.7,
#       'wind_degree': 265,
#       'wind_dir': 'W',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.06,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 77,
#       'cloud': 71,
#       'feelslike_c': 0.8,
#       'feelslike_f': 33.4,
#       'windchill_c': 0.8,
#       'windchill_f': 33.4,
#       'heatindex_c': 2.3,
#       'heatindex_f': 36.1,
#       'dewpoint_c': -1.4,
#       'dewpoint_f': 29.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 3.4,
#       'gust_kph': 5.4,
#       'uv': 0.5,
#       'short_rad': 373.68,
#       'diff_rad': 78.18,
#       'dni': 0.0,
#       'gti': 77.81},
#      {'time_epoch': 1767304800,
#       'time': '2026-01-01 17:00',
#       'temp_c': 2.2,
#       'temp_f': 36.0,
#       'is_day': 1,
#       'condition': {'text': 'Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#        'code': 1006},
#       'wind_mph': 3.1,
#       'wind_kph': 5.0,
#       'wind_degree': 269,
#       'wind_dir': 'W',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.05,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 75,
#       'cloud': 68,
#       'feelslike_c': 1.1,
#       'feelslike_f': 33.9,
#       'windchill_c': 1.1,
#       'windchill_f': 33.9,
#       'heatindex_c': 2.2,
#       'heatindex_f': 36.0,
#       'dewpoint_c': -1.4,
#       'dewpoint_f': 29.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 3.8,
#       'gust_kph': 6.2,
#       'uv': 0.0,
#       'short_rad': 310.1,
#       'diff_rad': 68.8,
#       'dni': 0.0,
#       'gti': 68.07},
#      {'time_epoch': 1767308400,
#       'time': '2026-01-01 18:00',
#       'temp_c': 2.1,
#       'temp_f': 35.8,
#       'is_day': 0,
#       'condition': {'text': 'Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png',
#        'code': 1006},
#       'wind_mph': 2.2,
#       'wind_kph': 3.6,
#       'wind_degree': 268,
#       'wind_dir': 'W',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.06,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 77,
#       'cloud': 76,
#       'feelslike_c': 1.3,
#       'feelslike_f': 34.4,
#       'windchill_c': 1.3,
#       'windchill_f': 34.4,
#       'heatindex_c': 2.1,
#       'heatindex_f': 35.8,
#       'dewpoint_c': -1.3,
#       'dewpoint_f': 29.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 3.3,
#       'gust_kph': 5.3,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1767312000,
#       'time': '2026-01-01 19:00',
#       'temp_c': 2.0,
#       'temp_f': 35.5,
#       'is_day': 0,
#       'condition': {'text': 'Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png',
#        'code': 1006},
#       'wind_mph': 1.1,
#       'wind_kph': 1.8,
#       'wind_degree': 336,
#       'wind_dir': 'NNW',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.06,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 79,
#       'cloud': 81,
#       'feelslike_c': 1.6,
#       'feelslike_f': 34.8,
#       'windchill_c': 1.6,
#       'windchill_f': 34.8,
#       'heatindex_c': 2.0,
#       'heatindex_f': 35.5,
#       'dewpoint_c': -1.3,
#       'dewpoint_f': 29.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
# ...
#       'snow_cm': 0.0,
#       'humidity': 89,
#       'cloud': 74,
#       'feelslike_c': -0.1,
#       'feelslike_f': 31.8,
#       'windchill_c': -0.1,
#       'windchill_f': 31.8,
#       'heatindex_c': 1.6,
#       'heatindex_f': 34.8,
#       'dewpoint_c': -0.3,
#       'dewpoint_f': 31.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 3.7,
#       'gust_kph': 6.0,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1767362400,
#       'time': '2026-01-02 09:00',
#       'temp_c': 1.8,
#       'temp_f': 35.3,
#       'is_day': 1,
#       'condition': {'text': 'Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#        'code': 1006},
#       'wind_mph': 3.4,
#       'wind_kph': 5.4,
#       'wind_degree': 19,
#       'wind_dir': 'NNE',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.97,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 88,
#       'cloud': 87,
#       'feelslike_c': 0.7,
#       'feelslike_f': 33.2,
#       'windchill_c': 0.7,
#       'windchill_f': 33.2,
#       'heatindex_c': 1.8,
#       'heatindex_f': 35.3,
#       'dewpoint_c': -0.0,
#       'dewpoint_f': 32.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.6,
#       'gust_kph': 9.0,
#       'uv': 0.2,
#       'short_rad': 14.8,
#       'diff_rad': 7.14,
#       'dni': 17.15,
#       'gti': 3.71},
#      {'time_epoch': 1767366000,
#       'time': '2026-01-02 10:00',
#       'temp_c': 2.1,
#       'temp_f': 35.7,
#       'is_day': 1,
#       'condition': {'text': 'Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#        'code': 1006},
#       'wind_mph': 4.0,
#       'wind_kph': 6.5,
#       'wind_degree': 24,
#       'wind_dir': 'NNE',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.95,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 87,
#       'cloud': 94,
#       'feelslike_c': 1.5,
#       'feelslike_f': 34.7,
#       'windchill_c': 1.5,
#       'windchill_f': 34.7,
#       'heatindex_c': 2.1,
#       'heatindex_f': 35.7,
#       'dewpoint_c': 0.1,
#       'dewpoint_f': 32.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 6.0,
#       'gust_kph': 9.6,
#       'uv': 0.6,
#       'short_rad': 46.66,
#       'diff_rad': 23.5,
#       'dni': 63.51,
#       'gti': 9.4},
#      {'time_epoch': 1767369600,
#       'time': '2026-01-02 11:00',
#       'temp_c': 2.4,
#       'temp_f': 36.4,
#       'is_day': 1,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#        'code': 1009},
#       'wind_mph': 5.4,
#       'wind_kph': 8.6,
#       'wind_degree': 25,
#       'wind_dir': 'NNE',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.94,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 86,
#       'cloud': 100,
#       'feelslike_c': 1.6,
#       'feelslike_f': 34.9,
#       'windchill_c': 1.6,
#       'windchill_f': 34.9,
#       'heatindex_c': 2.4,
#       'heatindex_f': 36.4,
#       'dewpoint_c': 0.2,
#       'dewpoint_f': 32.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 6.9,
#       'gust_kph': 11.1,
#       'uv': 1.2,
#       'short_rad': 95.24,
#       'diff_rad': 47.06,
#       'dni': 199.53,
#       'gti': 0.0},
#      {'time_epoch': 1767373200,
#       'time': '2026-01-02 12:00',
#       'temp_c': 2.7,
#       'temp_f': 36.9,
#       'is_day': 1,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#        'code': 1009},
#       'wind_mph': 4.5,
#       'wind_kph': 7.2,
#       'wind_degree': 19,
#       'wind_dir': 'NNE',
#       'pressure_mb': 1013.0,
#       'pressure_in': 29.92,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 82,
#       'cloud': 100,
#       'feelslike_c': 1.6,
#       'feelslike_f': 34.8,
#       'windchill_c': 1.6,
#       'windchill_f': 34.8,
#       'heatindex_c': 2.7,
#       'heatindex_f': 36.9,
#       'dewpoint_c': 0.1,
#       'dewpoint_f': 32.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.4,
#       'gust_kph': 8.6,
#       'uv': 1.5,
#       'short_rad': 134.26,
#       'diff_rad': 66.9,
#       'dni': 787.61,
#       'gti': 0.0},
#      {'time_epoch': 1767376800,
#       'time': '2026-01-02 13:00',
#       'temp_c': 3.0,
#       'temp_f': 37.4,
#       'is_day': 1,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#        'code': 1009},
#       'wind_mph': 3.8,
#       'wind_kph': 6.1,
#       'wind_degree': 11,
#       'wind_dir': 'NNE',
#       'pressure_mb': 1013.0,
#       'pressure_in': 29.92,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 80,
#       'cloud': 100,
#       'feelslike_c': 1.4,
#       'feelslike_f': 34.6,
#       'windchill_c': 1.4,
#       'windchill_f': 34.6,
#       'heatindex_c': 3.0,
#       'heatindex_f': 37.4,
#       'dewpoint_c': 0.0,
#       'dewpoint_f': 32.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.4,
#       'gust_kph': 7.1,
#       'uv': 1.8,
#       'short_rad': 167.16,
#       'diff_rad': 83.3,
#       'dni': 0.0,
#       'gti': 77.94},
#      {'time_epoch': 1767380400,
#       'time': '2026-01-02 14:00',
#       'temp_c': 3.3,
#       'temp_f': 38.0,
#       'is_day': 1,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#        'code': 1009},
#       'wind_mph': 5.4,
#       'wind_kph': 8.6,
#       'wind_degree': 9,
#       'wind_dir': 'N',
#       'pressure_mb': 1013.0,
#       'pressure_in': 29.91,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 79,
#       'cloud': 100,
#       'feelslike_c': 1.4,
#       'feelslike_f': 34.6,
#       'windchill_c': 1.4,
#       'windchill_f': 34.6,
#       'heatindex_c': 3.3,
#       'heatindex_f': 38.0,
#       'dewpoint_c': -0.0,
#       'dewpoint_f': 31.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 6.2,
#       'gust_kph': 9.9,
#       'uv': 1.3,
#       'short_rad': 340.86,
#       'diff_rad': 166.19,
#       'dni': 0.0,
#       'gti': 155.67},
#      {'time_epoch': 1767384000,
#       'time': '2026-01-02 15:00',
#       'temp_c': 3.5,
#       'temp_f': 38.4,
#       'is_day': 1,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#        'code': 1009},
#       'wind_mph': 5.1,
#       'wind_kph': 8.3,
#       'wind_degree': 4,
#       'wind_dir': 'N',
#       'pressure_mb': 1013.0,
#       'pressure_in': 29.91,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 77,
#       'cloud': 94,
#       'feelslike_c': 1.5,
#       'feelslike_f': 34.7,
#       'windchill_c': 1.5,
#       'windchill_f': 34.7,
#       'heatindex_c': 3.5,
#       'heatindex_f': 38.4,
#       'dewpoint_c': 0.0,
#       'dewpoint_f': 32.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 6.0,
#       'gust_kph': 9.6,
#       'uv': 0.9,
#       'short_rad': 293.56,
#       'diff_rad': 145.1,
#       'dni': 0.0,
#       'gti': 135.83},
#      {'time_epoch': 1767387600,
#       'time': '2026-01-02 16:00',
#       'temp_c': 3.7,
#       'temp_f': 38.7,
#       'is_day': 1,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#        'code': 1009},
#       'wind_mph': 6.0,
#       'wind_kph': 9.7,
#       'wind_degree': 1,
#       'wind_dir': 'N',
#       'pressure_mb': 1013.0,
#       'pressure_in': 29.91,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 77,
#       'cloud': 91,
#       'feelslike_c': 1.6,
#       'feelslike_f': 34.9,
#       'windchill_c': 1.6,
#       'windchill_f': 34.9,
#       'heatindex_c': 3.7,
#       'heatindex_f': 38.7,
#       'dewpoint_c': 0.1,
#       'dewpoint_f': 32.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 7.2,
#       'gust_kph': 11.7,
#       'uv': 0.4,
#       'short_rad': 252.86,
#       'diff_rad': 125.34,
#       'dni': 0.0,
#       'gti': 117.31},
#      {'time_epoch': 1767391200,
#       'time': '2026-01-02 17:00',
#       'temp_c': 3.4,
#       'temp_f': 38.0,
#       'is_day': 1,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#        'code': 1009},
#       'wind_mph': 6.7,
#       'wind_kph': 10.8,
#       'wind_degree': 358,
#       'wind_dir': 'N',
#       'pressure_mb': 1013.0,
#       'pressure_in': 29.9,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 76,
#       'cloud': 89,
#       'feelslike_c': 1.1,
#       'feelslike_f': 34.0,
#       'windchill_c': 1.1,
#       'windchill_f': 34.0,
#       'heatindex_c': 3.4,
#       'heatindex_f': 38.0,
#       'dewpoint_c': 0.1,
#       'dewpoint_f': 32.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 8.4,
#       'gust_kph': 13.5,
#       'uv': 0.0,
#       'short_rad': 210.14,
#       'diff_rad': 104.26,
#       'dni': 0.0,
#       'gti': 97.58},
#      {'time_epoch': 1767394800,
#       'time': '2026-01-02 18:00',
#       'temp_c': 3.0,
#       'temp_f': 37.3,
#       'is_day': 0,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#        'code': 1009},
#       'wind_mph': 6.5,
#       'wind_kph': 10.4,
#       'wind_degree': 358,
#       'wind_dir': 'N',
#       'pressure_mb': 1013.0,
#       'pressure_in': 29.93,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 78,
#       'cloud': 94,
#       'feelslike_c': 0.6,
#       'feelslike_f': 33.1,
#       'windchill_c': 0.6,
#       'windchill_f': 33.1,
#       'heatindex_c': 3.0,
#       'heatindex_f': 37.3,
#       'dewpoint_c': -0.4,
#       'dewpoint_f': 31.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 8.9,
#       'gust_kph': 14.3,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1767398400,
#       'time': '2026-01-02 19:00',
#       'temp_c': 2.5,
#       'temp_f': 36.5,
#       'is_day': 0,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#        'code': 1009},
#       'wind_mph': 6.5,
#       'wind_kph': 10.4,
#       'wind_degree': 3,
#       'wind_dir': 'N',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.94,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 79,
#       'cloud': 97,
#       'feelslike_c': 0.1,
#       'feelslike_f': 32.1,
#       'windchill_c': 0.1,
#       'windchill_f': 32.1,
#       'heatindex_c': 2.5,
#       'heatindex_f': 36.5,
#       'dewpoint_c': -0.6,
#       'dewpoint_f': 30.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.0,
#       'gust_kph': 16.1,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1767402000,
#       'time': '2026-01-02 20:00',
#       'temp_c': 1.3,
#       'temp_f': 34.4,
#       'is_day': 0,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#        'code': 1009},
#       'wind_mph': 6.9,
#       'wind_kph': 11.2,
#       'wind_degree': 10,
#       'wind_dir': 'N',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.95,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 81,
#       'cloud': 100,
#       'feelslike_c': -1.8,
#       'feelslike_f': 28.8,
#       'windchill_c': -1.8,
#       'windchill_f': 28.8,
#       'heatindex_c': 1.3,
#       'heatindex_f': 34.4,
#       'dewpoint_c': -0.9,
#       'dewpoint_f': 30.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.9,
#       'gust_kph': 17.6,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1767405600,
#       'time': '2026-01-02 21:00',
#       'temp_c': 0.3,
#       'temp_f': 32.6,
#       'is_day': 0,
#       'condition': {'text': 'Clear ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 7.4,
#       'wind_kph': 11.9,
#       'wind_degree': 9,
#       'wind_dir': 'N',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.97,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 57,
#       'cloud': 5,
#       'feelslike_c': -3.2,
#       'feelslike_f': 26.2,
#       'windchill_c': -3.2,
#       'windchill_f': 26.2,
#       'heatindex_c': 0.3,
#       'heatindex_f': 32.6,
#       'dewpoint_c': -7.3,
#       'dewpoint_f': 18.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.5,
#       'gust_kph': 18.5,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1767409200,
#       'time': '2026-01-02 22:00',
#       'temp_c': 1.2,
#       'temp_f': 34.2,
#       'is_day': 0,
#       'condition': {'text': 'Clear ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 7.6,
#       'wind_kph': 12.2,
#       'wind_degree': 9,
#       'wind_dir': 'N',
#       'pressure_mb': 1016.0,
#       'pressure_in': 29.99,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 55,
#       'cloud': 5,
#       'feelslike_c': -0.6,
#       'feelslike_f': 31.0,
#       'windchill_c': -0.6,
#       'windchill_f': 31.0,
#       'heatindex_c': 1.2,
#       'heatindex_f': 34.2,
#       'dewpoint_c': -8.5,
#       'dewpoint_f': 16.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.6,
#       'gust_kph': 18.6,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1767412800,
#       'time': '2026-01-02 23:00',
#       'temp_c': -0.3,
#       'temp_f': 31.5,
#       'is_day': 0,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#        'code': 1009},
#       'wind_mph': 6.9,
#       'wind_kph': 11.2,
#       'wind_degree': 11,
#       'wind_dir': 'NNE',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.07,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 81,
#       'cloud': 97,
#       'feelslike_c': -3.1,
#       'feelslike_f': 26.5,
#       'windchill_c': -3.1,
#       'windchill_f': 26.5,
#       'heatindex_c': -0.3,
#       'heatindex_f': 31.5,
#       'dewpoint_c': -0.8,
#       'dewpoint_f': 30.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.4,
#       'gust_kph': 16.8,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0}]}]}}

# %%
forecast_data = forecast_response.json()
forecast = forecast_data['forecast']['forecastday']

# %%
forecast_data['forecast']
# Out:
# {'forecastday': [{'date': '2025-12-31',
#    'date_epoch': 1767139200,
#    'day': {'maxtemp_c': 2.9,
#     'maxtemp_f': 37.2,
#     'mintemp_c': -0.6,
#     'mintemp_f': 30.9,
#     'avgtemp_c': 0.9,
#     'avgtemp_f': 33.7,
#     'maxwind_mph': 10.5,
#     'maxwind_kph': 16.9,
#     'totalprecip_mm': 0.0,
#     'totalprecip_in': 0.0,
#     'totalsnow_cm': 0.0,
#     'avgvis_km': 10.0,
#     'avgvis_miles': 6.0,
#     'avghumidity': 77,
#     'daily_will_it_rain': 0,
#     'daily_chance_of_rain': 0,
#     'daily_will_it_snow': 0,
#     'daily_chance_of_snow': 0,
#     'condition': {'text': 'Overcast ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#      'code': 1009},
#     'uv': 0.3},
#    'astro': {'sunrise': '08:00 AM',
#     'sunset': '05:33 PM',
#     'moonrise': '02:36 PM',
#     'moonset': '05:05 AM',
#     'moon_phase': 'Waxing Gibbous',
#     'moon_illumination': 84,
#     'is_moon_up': 1,
#     'is_sun_up': 0},
#    'hour': [{'time_epoch': 1767157200,
#      'time': '2025-12-31 00:00',
#      'temp_c': -0.6,
#      'temp_f': 30.9,
#      'is_day': 0,
#      'condition': {'text': 'Clear ',
#       'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#       'code': 1000},
#      'wind_mph': 8.5,
#      'wind_kph': 13.7,
#      'wind_degree': 240,
#      'wind_dir': 'WSW',
#      'pressure_mb': 1020.0,
#      'pressure_in': 30.12,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'snow_cm': 0.0,
#      'humidity': 68,
#      'cloud': 0,
#      'feelslike_c': -4.5,
#      'feelslike_f': 23.9,
#      'windchill_c': -4.5,
#      'windchill_f': 23.9,
#      'heatindex_c': -0.6,
#      'heatindex_f': 30.9,
#      'dewpoint_c': -5.7,
#      'dewpoint_f': 21.8,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 12.1,
#      'gust_kph': 19.5,
#      'uv': 0,
#      'short_rad': 0,
#      'diff_rad': 0,
#      'dni': 0,
#      'gti': 0},
#     {'time_epoch': 1767160800,
#      'time': '2025-12-31 01:00',
#      'temp_c': -0.5,
#      'temp_f': 31.0,
#      'is_day': 0,
#      'condition': {'text': 'Clear ',
#       'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#       'code': 1000},
#      'wind_mph': 8.9,
#      'wind_kph': 14.4,
#      'wind_degree': 238,
#      'wind_dir': 'WSW',
#      'pressure_mb': 1019.0,
#      'pressure_in': 30.09,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'snow_cm': 0.0,
#      'humidity': 67,
#      'cloud': 0,
#      'feelslike_c': -4.2,
#      'feelslike_f': 24.4,
#      'windchill_c': -4.2,
#      'windchill_f': 24.4,
#      'heatindex_c': -0.5,
#      'heatindex_f': 31.0,
#      'dewpoint_c': -5.8,
#      'dewpoint_f': 21.6,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 12.7,
#      'gust_kph': 20.5,
#      'uv': 0,
#      'short_rad': 0,
#      'diff_rad': 0,
#      'dni': 0,
#      'gti': 0},
#     {'time_epoch': 1767164400,
#      'time': '2025-12-31 02:00',
#      'temp_c': -0.5,
#      'temp_f': 31.2,
#      'is_day': 0,
#      'condition': {'text': 'Clear ',
#       'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#       'code': 1000},
#      'wind_mph': 8.9,
#      'wind_kph': 14.4,
#      'wind_degree': 234,
#      'wind_dir': 'SW',
#      'pressure_mb': 1018.0,
#      'pressure_in': 30.06,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'snow_cm': 0.0,
#      'humidity': 68,
#      'cloud': 0,
#      'feelslike_c': -4.2,
#      'feelslike_f': 24.5,
#      'windchill_c': -4.2,
#      'windchill_f': 24.5,
#      'heatindex_c': -0.5,
#      'heatindex_f': 31.2,
#      'dewpoint_c': -5.7,
#      'dewpoint_f': 21.8,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 12.7,
#      'gust_kph': 20.5,
#      'uv': 0,
#      'short_rad': 0,
#      'diff_rad': 0,
#      'dni': 0,
#      'gti': 0},
#     {'time_epoch': 1767168000,
#      'time': '2025-12-31 03:00',
#      'temp_c': -0.4,
#      'temp_f': 31.3,
#      'is_day': 0,
#      'condition': {'text': 'Clear ',
#       'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#       'code': 1000},
#      'wind_mph': 9.2,
#      'wind_kph': 14.8,
#      'wind_degree': 237,
#      'wind_dir': 'WSW',
#      'pressure_mb': 1017.0,
#      'pressure_in': 30.04,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'snow_cm': 0.0,
#      'humidity': 68,
#      'cloud': 0,
#      'feelslike_c': -4.4,
#      'feelslike_f': 24.1,
#      'windchill_c': -4.4,
#      'windchill_f': 24.1,
#      'heatindex_c': -0.4,
#      'heatindex_f': 31.3,
#      'dewpoint_c': -5.5,
#      'dewpoint_f': 22.1,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 13.2,
#      'gust_kph': 21.3,
#      'uv': 0,
#      'short_rad': 0,
#      'diff_rad': 0,
#      'dni': 0,
#      'gti': 0},
#     {'time_epoch': 1767171600,
#      'time': '2025-12-31 04:00',
#      'temp_c': -0.3,
#      'temp_f': 31.4,
#      'is_day': 0,
#      'condition': {'text': 'Clear ',
#       'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#       'code': 1000},
#      'wind_mph': 9.8,
#      'wind_kph': 15.8,
#      'wind_degree': 234,
#      'wind_dir': 'SW',
#      'pressure_mb': 1017.0,
#      'pressure_in': 30.02,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'snow_cm': 0.0,
#      'humidity': 70,
#      'cloud': 0,
#      'feelslike_c': -4.6,
#      'feelslike_f': 23.8,
#      'windchill_c': -4.6,
#      'windchill_f': 23.8,
#      'heatindex_c': -0.3,
#      'heatindex_f': 31.4,
#      'dewpoint_c': -5.1,
#      'dewpoint_f': 22.8,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 14.1,
#      'gust_kph': 22.7,
#      'uv': 0,
#      'short_rad': 0,
#      'diff_rad': 0,
#      'dni': 0,
#      'gti': 0},
#     {'time_epoch': 1767175200,
#      'time': '2025-12-31 05:00',
#      'temp_c': -0.3,
#      'temp_f': 31.4,
#      'is_day': 0,
#      'condition': {'text': 'Clear ',
#       'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#       'code': 1000},
#      'wind_mph': 10.5,
#      'wind_kph': 16.9,
#      'wind_degree': 235,
#      'wind_dir': 'SW',
#      'pressure_mb': 1016.0,
#      'pressure_in': 30.01,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'snow_cm': 0.0,
#      'humidity': 71,
#      'cloud': 0,
#      'feelslike_c': -4.2,
#      'feelslike_f': 24.5,
#      'windchill_c': -4.2,
#      'windchill_f': 24.5,
#      'heatindex_c': -0.3,
#      'heatindex_f': 31.4,
#      'dewpoint_c': -5.0,
#      'dewpoint_f': 23.0,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 15.3,
#      'gust_kph': 24.7,
#      'uv': 0,
#      'short_rad': 0,
#      'diff_rad': 0,
#      'dni': 0,
#      'gti': 0},
#     {'time_epoch': 1767178800,
#      'time': '2025-12-31 06:00',
#      'temp_c': -0.3,
#      'temp_f': 31.4,
#      'is_day': 0,
#      'condition': {'text': 'Clear ',
#       'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#       'code': 1000},
#      'wind_mph': 9.8,
#      'wind_kph': 15.8,
#      'wind_degree': 242,
#      'wind_dir': 'WSW',
#      'pressure_mb': 1016.0,
#      'pressure_in': 30.01,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'snow_cm': 0.0,
#      'humidity': 75,
#      'cloud': 0,
#      'feelslike_c': -3.9,
#      'feelslike_f': 24.9,
#      'windchill_c': -3.9,
#      'windchill_f': 24.9,
#      'heatindex_c': -0.3,
#      'heatindex_f': 31.4,
#      'dewpoint_c': -4.2,
#      'dewpoint_f': 24.5,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 14.4,
#      'gust_kph': 23.2,
#      'uv': 0,
#      'short_rad': 0,
#      'diff_rad': 0,
#      'dni': 0,
#      'gti': 0},
#     {'time_epoch': 1767182400,
#      'time': '2025-12-31 07:00',
#      'temp_c': -0.3,
#      'temp_f': 31.5,
#      'is_day': 0,
#      'condition': {'text': 'Clear ',
#       'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#       'code': 1000},
#      'wind_mph': 8.9,
#      'wind_kph': 14.4,
#      'wind_degree': 245,
#      'wind_dir': 'WSW',
#      'pressure_mb': 1017.0,
#      'pressure_in': 30.02,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'snow_cm': 0.0,
#      'humidity': 76,
#      'cloud': 0,
#      'feelslike_c': -3.8,
#      'feelslike_f': 25.2,
#      'windchill_c': -3.8,
#      'windchill_f': 25.2,
#      'heatindex_c': -0.3,
#      'heatindex_f': 31.5,
#      'dewpoint_c': -3.9,
#      'dewpoint_f': 24.9,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 13.0,
#      'gust_kph': 20.8,
#      'uv': 0,
#      'short_rad': 0,
#      'diff_rad': 0,
#      'dni': 0,
#      'gti': 0},
#     {'time_epoch': 1767186000,
#      'time': '2025-12-31 08:00',
#      'temp_c': -0.6,
#      'temp_f': 30.9,
#      'is_day': 1,
#      'condition': {'text': 'Overcast',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#       'code': 1009},
#      'wind_mph': 8.5,
#      'wind_kph': 13.7,
#      'wind_degree': 246,
#      'wind_dir': 'WSW',
#      'pressure_mb': 1017.0,
#      'pressure_in': 30.03,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'snow_cm': 0.0,
#      'humidity': 61,
#      'cloud': 100,
#      'feelslike_c': -3.7,
#      'feelslike_f': 25.3,
#      'windchill_c': -3.7,
#      'windchill_f': 25.3,
#      'heatindex_c': -0.3,
#      'heatindex_f': 31.5,
#      'dewpoint_c': -3.7,
#      'dewpoint_f': 25.3,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 16.0,
#      'vis_miles': 9.0,
#      'gust_mph': 12.3,
#      'gust_kph': 19.8,
#      'uv': 0.0,
#      'short_rad': 0.0,
#      'diff_rad': 0.0,
#      'dni': 0.0,
#      'gti': 0.0},
#     {'time_epoch': 1767189600,
#      'time': '2025-12-31 09:00',
#      'temp_c': -0.1,
#      'temp_f': 31.9,
#      'is_day': 1,
#      'condition': {'text': 'Sunny',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#       'code': 1000},
#      'wind_mph': 7.8,
#      'wind_kph': 12.6,
#      'wind_degree': 252,
#      'wind_dir': 'WSW',
#      'pressure_mb': 1017.0,
#      'pressure_in': 30.02,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'snow_cm': 0.0,
#      'humidity': 78,
#      'cloud': 0,
#      'feelslike_c': -3.7,
#      'feelslike_f': 25.3,
#      'windchill_c': -3.7,
#      'windchill_f': 25.3,
#      'heatindex_c': -0.1,
#      'heatindex_f': 31.9,
#      'dewpoint_c': -3.6,
#      'dewpoint_f': 25.6,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 11.1,
#      'gust_kph': 17.9,
#      'uv': 0.2,
#      'short_rad': 15.12,
#      'diff_rad': 7.07,
#      'dni': 18.17,
#      'gti': 3.42},
#     {'time_epoch': 1767193200,
#      'time': '2025-12-31 10:00',
#      'temp_c': 0.5,
#      'temp_f': 32.8,
#      'is_day': 1,
#      'condition': {'text': 'Sunny',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#       'code': 1000},
#      'wind_mph': 7.8,
#      'wind_kph': 12.6,
#      'wind_degree': 250,
#      'wind_dir': 'WSW',
#      'pressure_mb': 1017.0,
#      'pressure_in': 30.03,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'snow_cm': 0.0,
#      'humidity': 78,
#      'cloud': 8,
#      'feelslike_c': -3.5,
#      'feelslike_f': 25.7,
#      'windchill_c': -3.5,
#      'windchill_f': 25.7,
#      'heatindex_c': 0.5,
#      'heatindex_f': 32.8,
#      'dewpoint_c': -3.2,
#      'dewpoint_f': 26.2,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 10.3,
#      'gust_kph': 16.5,
#      'uv': 0.6,
#      'short_rad': 51.22,
#      'diff_rad': 24.1,
#      'dni': 75.22,
#      'gti': 7.45},
#     {'time_epoch': 1767196800,
#      'time': '2025-12-31 11:00',
#      'temp_c': 1.2,
#      'temp_f': 34.1,
#      'is_day': 1,
#      'condition': {'text': 'Overcast ',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#       'code': 1009},
#      'wind_mph': 8.5,
#      'wind_kph': 13.7,
#      'wind_degree': 262,
#      'wind_dir': 'W',
#      'pressure_mb': 1017.0,
#      'pressure_in': 30.04,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'snow_cm': 0.0,
#      'humidity': 78,
#      'cloud': 100,
#      'feelslike_c': -2.8,
#      'feelslike_f': 27.0,
#      'windchill_c': -2.8,
#      'windchill_f': 27.0,
#      'heatindex_c': 1.2,
#      'heatindex_f': 34.1,
#      'dewpoint_c': -2.3,
#      'dewpoint_f': 27.8,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 10.7,
#      'gust_kph': 17.2,
#      'uv': 1.0,
#      'short_rad': 88.12,
#      'diff_rad': 42.5,
#      'dni': 192.51,
#      'gti': 0.0},
#     {'time_epoch': 1767200400,
#      'time': '2025-12-31 12:00',
#      'temp_c': 1.9,
#      'temp_f': 35.5,
#      'is_day': 1,
#      'condition': {'text': 'Overcast ',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#       'code': 1009},
#      'wind_mph': 8.3,
#      'wind_kph': 13.3,
#      'wind_degree': 263,
#      'wind_dir': 'W',
#      'pressure_mb': 1017.0,
#      'pressure_in': 30.02,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'snow_cm': 0.0,
#      'humidity': 80,
#      'cloud': 100,
#      'feelslike_c': -2.0,
#      'feelslike_f': 28.4,
#      'windchill_c': -2.0,
#      'windchill_f': 28.4,
#      'heatindex_c': 1.9,
#      'heatindex_f': 35.5,
#      'dewpoint_c': -1.2,
#      'dewpoint_f': 29.9,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 10.1,
#      'gust_kph': 16.3,
#      'uv': 1.4,
#      'short_rad': 129.14,
#      'diff_rad': 62.61,
#      'dni': 823.81,
#      'gti': 0.0},
#     {'time_epoch': 1767204000,
#      'time': '2025-12-31 13:00',
#      'temp_c': 2.4,
#      'temp_f': 36.4,
#      'is_day': 1,
#      'condition': {'text': 'Overcast ',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#       'code': 1009},
#      'wind_mph': 8.5,
#      'wind_kph': 13.7,
#      'wind_degree': 258,
#      'wind_dir': 'WSW',
#      'pressure_mb': 1016.0,
#      'pressure_in': 30.0,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'snow_cm': 0.0,
#      'humidity': 81,
#      'cloud': 100,
#      'feelslike_c': -1.5,
#      'feelslike_f': 29.4,
#      'windchill_c': -1.5,
#      'windchill_f': 29.4,
#      'heatindex_c': 2.4,
#      'heatindex_f': 36.4,
#      'dewpoint_c': -0.2,
#      'dewpoint_f': 31.7,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 10.2,
#      'gust_kph': 16.5,
#      'uv': 1.5,
#      'short_rad': 161.9,
#      'diff_rad': 78.08,
#      'dni': 0.0,
#      'gti': 73.17},
#     {'time_epoch': 1767207600,
#      'time': '2025-12-31 14:00',
#      'temp_c': 2.6,
#      'temp_f': 36.7,
#      'is_day': 1,
#      'condition': {'text': 'Overcast ',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#       'code': 1009},
#      'wind_mph': 9.2,
#      'wind_kph': 14.8,
#      'wind_degree': 258,
#      'wind_dir': 'WSW',
#      'pressure_mb': 1015.0,
#      'pressure_in': 29.96,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'snow_cm': 0.0,
#      'humidity': 80,
#      'cloud': 100,
#      'feelslike_c': -1.0,
#      'feelslike_f': 30.2,
#      'windchill_c': -1.0,
#      'windchill_f': 30.2,
#      'heatindex_c': 2.6,
#      'heatindex_f': 36.7,
#      'dewpoint_c': -0.2,
#      'dewpoint_f': 31.6,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 11.2,
#      'gust_kph': 18.0,
#      'uv': 1.5,
#      'short_rad': 304.84,
#      'diff_rad': 150.43,
#      'dni': 0.0,
#      'gti': 140.83},
#     {'time_epoch': 1767211200,
#      'time': '2025-12-31 15:00',
#      'temp_c': 2.7,
#      'temp_f': 36.9,
#      'is_day': 1,
#      'condition': {'text': 'Overcast ',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#       'code': 1009},
#      'wind_mph': 8.9,
#      'wind_kph': 14.4,
#      'wind_degree': 261,
#      'wind_dir': 'W',
#      'pressure_mb': 1015.0,
#      'pressure_in': 29.96,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'snow_cm': 0.0,
#      'humidity': 82,
#      'cloud': 100,
#      'feelslike_c': -0.8,
#      'feelslike_f': 30.5,
#      'windchill_c': -0.8,
#      'windchill_f': 30.5,
#      'heatindex_c': 2.7,
#      'heatindex_f': 36.9,
#      'dewpoint_c': 0.0,
#      'dewpoint_f': 32.0,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 11.2,
#      'gust_kph': 18.0,
#      'uv': 0.8,
#      'short_rad': 285.42,
#      'diff_rad': 139.55,
#      'dni': 0.0,
#      'gti': 130.7},
#     {'time_epoch': 1767214800,
#      'time': '2025-12-31 16:00',
#      'temp_c': 2.8,
#      'temp_f': 37.0,
#      'is_day': 1,
#      'condition': {'text': 'Overcast ',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#       'code': 1009},
#      'wind_mph': 9.2,
#      'wind_kph': 14.8,
#      'wind_degree': 248,
#      'wind_dir': 'WSW',
#      'pressure_mb': 1014.0,
#      'pressure_in': 29.93,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'snow_cm': 0.0,
#      'humidity': 83,
#      'cloud': 100,
#      'feelslike_c': -0.6,
#      'feelslike_f': 30.8,
#      'windchill_c': -0.6,
#      'windchill_f': 30.8,
#      'heatindex_c': 2.8,
#      'heatindex_f': 37.0,
#      'dewpoint_c': 0.3,
#      'dewpoint_f': 32.5,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 12.1,
#      'gust_kph': 19.4,
#      'uv': 0.4,
#      'short_rad': 253.98,
#      'diff_rad': 123.62,
#      'dni': 0.0,
#      'gti': 115.8},
#     {'time_epoch': 1767218400,
#      'time': '2025-12-31 17:00',
#      'temp_c': 2.8,
#      'temp_f': 37.0,
#      'is_day': 1,
#      'condition': {'text': 'Overcast ',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#       'code': 1009},
#      'wind_mph': 9.2,
#      'wind_kph': 14.8,
#      'wind_degree': 255,
#      'wind_dir': 'WSW',
#      'pressure_mb': 1013.0,
#      'pressure_in': 29.93,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'snow_cm': 0.0,
#      'humidity': 83,
#      'cloud': 100,
#      'feelslike_c': -0.5,
#      'feelslike_f': 31.1,
#      'windchill_c': -0.5,
#      'windchill_f': 31.1,
#      'heatindex_c': 2.8,
#      'heatindex_f': 37.0,
#      'dewpoint_c': 0.4,
#      'dewpoint_f': 32.6,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 12.6,
#      'gust_kph': 20.3,
#      'uv': 0.0,
#      'short_rad': 211.7,
#      'diff_rad': 103.03,
#      'dni': 0.0,
#      'gti': 96.52},
#     {'time_epoch': 1767222000,
#      'time': '2025-12-31 18:00',
#      'temp_c': 1.9,
#      'temp_f': 35.3,
#      'is_day': 0,
#      'condition': {'text': 'Overcast ',
#       'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#       'code': 1009},
#      'wind_mph': 9.2,
#      'wind_kph': 14.8,
#      'wind_degree': 254,
#      'wind_dir': 'WSW',
#      'pressure_mb': 1014.0,
#      'pressure_in': 29.94,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'snow_cm': 0.0,
#      'humidity': 85,
#      'cloud': 100,
#      'feelslike_c': -2.0,
#      'feelslike_f': 28.4,
#      'windchill_c': -2.0,
#      'windchill_f': 28.4,
#      'heatindex_c': 1.9,
#      'heatindex_f': 35.3,
#      'dewpoint_c': 0.5,
#      'dewpoint_f': 32.8,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 13.7,
#      'gust_kph': 22.0,
#      'uv': 0,
#      'short_rad': 0,
#      'diff_rad': 0,
#      'dni': 0,
#      'gti': 0},
#     {'time_epoch': 1767225600,
#      'time': '2025-12-31 19:00',
#      'temp_c': 1.7,
#      'temp_f': 35.0,
#      'is_day': 0,
#      'condition': {'text': 'Partly Cloudy ',
#       'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#       'code': 1003},
#      'wind_mph': 8.3,
#      'wind_kph': 13.3,
#      'wind_degree': 255,
#      'wind_dir': 'WSW',
#      'pressure_mb': 1014.0,
#      'pressure_in': 29.95,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'snow_cm': 0.0,
#      'humidity': 78,
#      'cloud': 38,
#      'feelslike_c': -2.5,
#      'feelslike_f': 27.5,
#      'windchill_c': -2.5,
#      'windchill_f': 27.5,
#      'heatindex_c': 1.7,
#      'heatindex_f': 35.0,
#      'dewpoint_c': -2.5,
#      'dewpoint_f': 27.6,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 13.1,
#      'gust_kph': 21.1,
#      'uv': 0,
#      'short_rad': 0,
#      'diff_rad': 0,
#      'dni': 0,
#      'gti': 0},
#     {'time_epoch': 1767229200,
#      'time': '2025-12-31 20:00',
#      'temp_c': 1.7,
#      'temp_f': 35.0,
#      'is_day': 0,
#      'condition': {'text': 'Partly Cloudy ',
#       'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#       'code': 1003},
#      'wind_mph': 8.5,
#      'wind_kph': 13.7,
#      'wind_degree': 248,
#      'wind_dir': 'WSW',
#      'pressure_mb': 1015.0,
#      'pressure_in': 29.96,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'snow_cm': 0.0,
#      'humidity': 79,
#      'cloud': 59,
#      'feelslike_c': -2.7,
#      'feelslike_f': 27.2,
#      'windchill_c': -2.7,
#      'windchill_f': 27.2,
#      'heatindex_c': 1.7,
#      'heatindex_f': 35.0,
#      'dewpoint_c': -1.7,
#      'dewpoint_f': 29.0,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 13.3,
#      'gust_kph': 21.4,
#      'uv': 0,
#      'short_rad': 0,
#      'diff_rad': 0,
#      'dni': 0,
#      'gti': 0},
#     {'time_epoch': 1767232800,
#      'time': '2025-12-31 21:00',
#      'temp_c': 1.7,
#      'temp_f': 35.0,
#      'is_day': 0,
#      'condition': {'text': 'Partly Cloudy ',
#       'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#       'code': 1003},
#      'wind_mph': 9.2,
#      'wind_kph': 14.8,
#      'wind_degree': 253,
#      'wind_dir': 'WSW',
#      'pressure_mb': 1015.0,
#      'pressure_in': 29.97,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'snow_cm': 0.0,
#      'humidity': 81,
#      'cloud': 79,
#      'feelslike_c': -2.7,
#      'feelslike_f': 27.1,
#      'windchill_c': -2.7,
#      'windchill_f': 27.1,
#      'heatindex_c': 1.7,
#      'heatindex_f': 35.0,
#      'dewpoint_c': -1.2,
#      'dewpoint_f': 29.8,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 13.9,
#      'gust_kph': 22.4,
#      'uv': 0,
#      'short_rad': 0,
#      'diff_rad': 0,
#      'dni': 0,
#      'gti': 0},
#     {'time_epoch': 1767236400,
#      'time': '2025-12-31 22:00',
#      'temp_c': 1.1,
#      'temp_f': 33.9,
#      'is_day': 0,
#      'condition': {'text': 'Partly Cloudy ',
#       'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#       'code': 1003},
#      'wind_mph': 8.9,
#      'wind_kph': 14.4,
#      'wind_degree': 256,
#      'wind_dir': 'WSW',
#      'pressure_mb': 1015.0,
#      'pressure_in': 29.97,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'snow_cm': 0.0,
#      'humidity': 82,
#      'cloud': 90,
#      'feelslike_c': -3.2,
#      'feelslike_f': 26.2,
#      'windchill_c': -3.2,
#      'windchill_f': 26.2,
#      'heatindex_c': 1.1,
#      'heatindex_f': 33.9,
#      'dewpoint_c': -1.0,
#      'dewpoint_f': 30.2,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 13.4,
#      'gust_kph': 21.6,
#      'uv': 0,
#      'short_rad': 0,
#      'diff_rad': 0,
#      'dni': 0,
#      'gti': 0},
#     {'time_epoch': 1767240000,
#      'time': '2025-12-31 23:00',
#      'temp_c': 1.2,
#      'temp_f': 34.2,
#      'is_day': 0,
#      'condition': {'text': 'Partly Cloudy ',
#       'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#       'code': 1003},
#      'wind_mph': 8.7,
#      'wind_kph': 14.0,
#      'wind_degree': 256,
#      'wind_dir': 'WSW',
#      'pressure_mb': 1015.0,
#      'pressure_in': 29.97,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'snow_cm': 0.0,
#      'humidity': 78,
#      'cloud': 49,
#      'feelslike_c': -3.1,
#      'feelslike_f': 26.5,
#      'windchill_c': -3.1,
#      'windchill_f': 26.5,
#      'heatindex_c': 1.2,
#      'heatindex_f': 34.2,
#      'dewpoint_c': -2.8,
#      'dewpoint_f': 26.9,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 13.6,
#      'gust_kph': 21.8,
#      'uv': 0,
#      'short_rad': 0,
#      'diff_rad': 0,
#      'dni': 0,
#      'gti': 0}]},
#   {'date': '2026-01-01',
#    'date_epoch': 1767225600,
#    'day': {'maxtemp_c': 2.6,
#     'maxtemp_f': 36.7,
#     'mintemp_c': 0.3,
#     'mintemp_f': 32.5,
#     'avgtemp_c': 1.3,
#     'avgtemp_f': 34.3,
#     'maxwind_mph': 8.7,
#     'maxwind_kph': 14.0,
#     'totalprecip_mm': 0.0,
#     'totalprecip_in': 0.0,
#     'totalsnow_cm': 0.0,
#     'avgvis_km': 10.0,
#     'avgvis_miles': 6.0,
#     'avghumidity': 84,
#     'daily_will_it_rain': 0,
#     'daily_chance_of_rain': 0,
#     'daily_will_it_snow': 0,
#     'daily_chance_of_snow': 0,
#     'condition': {'text': 'Cloudy ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#      'code': 1006},
#     'uv': 0.4},
#    'astro': {'sunrise': '08:00 AM',
#     'sunset': '05:34 PM',
#     'moonrise': '03:32 PM',
#     'moonset': '06:21 AM',
#     'moon_phase': 'Waxing Gibbous',
#     'moon_illumination': 91,
#     'is_moon_up': 1,
#     'is_sun_up': 0},
#    'hour': [{'time_epoch': 1767243600,
#      'time': '2026-01-01 00:00',
#      'temp_c': 1.2,
#      'temp_f': 34.2,
#      'is_day': 0,
#      'condition': {'text': 'Overcast ',
#       'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#       'code': 1009},
#      'wind_mph': 8.7,
#      'wind_kph': 14.0,
#      'wind_degree': 255,
#      'wind_dir': 'WSW',
#      'pressure_mb': 1015.0,
#      'pressure_in': 29.97,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'snow_cm': 0.0,
#      'humidity': 84,
#      'cloud': 100,
#      'feelslike_c': -3.0,
#      'feelslike_f': 26.6,
#      'windchill_c': -3.0,
#      'windchill_f': 26.6,
#      'heatindex_c': 1.2,
#      'heatindex_f': 34.2,
#      'dewpoint_c': -1.0,
#      'dewpoint_f': 30.1,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 13.6,
#      'gust_kph': 22.0,
#      'uv': 0,
#      'short_rad': 0,
#      'diff_rad': 0,
#      'dni': 0,
#      'gti': 0},
#     {'time_epoch': 1767247200,
#      'time': '2026-01-01 01:00',
#      'temp_c': 1.1,
#      'temp_f': 34.0,
#      'is_day': 0,
#      'condition': {'text': 'Overcast ',
#       'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#       'code': 1009},
#      'wind_mph': 8.5,
#      'wind_kph': 13.7,
#      'wind_degree': 264,
#      'wind_dir': 'W',
#      'pressure_mb': 1015.0,
#      'pressure_in': 29.97,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'snow_cm': 0.0,
#      'humidity': 84,
#      'cloud': 100,
#      'feelslike_c': -3.0,
#      'feelslike_f': 26.5,
#      'windchill_c': -3.0,
#      'windchill_f': 26.5,
#      'heatindex_c': 1.1,
#      'heatindex_f': 34.0,
#      'dewpoint_c': -1.1,
#      'dewpoint_f': 29.9,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 13.1,
#      'gust_kph': 21.1,
#      'uv': 0,
#      'short_rad': 0,
#      'diff_rad': 0,
#      'dni': 0,
#      'gti': 0},
#     {'time_epoch': 1767250800,
#      'time': '2026-01-01 02:00',
#      'temp_c': 1.0,
#      'temp_f': 33.8,
#      'is_day': 0,
#      'condition': {'text': 'Overcast ',
#       'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#       'code': 1009},
#      'wind_mph': 7.8,
#      'wind_kph': 12.6,
#      'wind_degree': 272,
#      'wind_dir': 'W',
#      'pressure_mb': 1015.0,
#      'pressure_in': 29.97,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'snow_cm': 0.0,
#      'humidity': 85,
#      'cloud': 100,
#      'feelslike_c': -3.0,
#      'feelslike_f': 26.7,
#      'windchill_c': -3.0,
#      'windchill_f': 26.7,
#      'heatindex_c': 1.0,
#      'heatindex_f': 33.8,
#      'dewpoint_c': -1.3,
#      'dewpoint_f': 29.7,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 11.1,
#      'gust_kph': 17.8,
#      'uv': 0,
#      'short_rad': 0,
#      'diff_rad': 0,
#      'dni': 0,
#      'gti': 0},
#     {'time_epoch': 1767254400,
#      'time': '2026-01-01 03:00',
#      'temp_c': 0.9,
#      'temp_f': 33.6,
#      'is_day': 0,
#      'condition': {'text': 'Overcast ',
#       'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#       'code': 1009},
#      'wind_mph': 6.7,
#      'wind_kph': 10.8,
#      'wind_degree': 276,
#      'wind_dir': 'W',
#      'pressure_mb': 1015.0,
#      'pressure_in': 29.98,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'snow_cm': 0.0,
#      'humidity': 87,
#      'cloud': 100,
#      'feelslike_c': -2.9,
#      'feelslike_f': 26.8,
#      'windchill_c': -2.9,
#      'windchill_f': 26.8,
#      'heatindex_c': 0.9,
#      'heatindex_f': 33.6,
#      'dewpoint_c': -1.1,
#      'dewpoint_f': 30.0,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 9.5,
#      'gust_kph': 15.2,
#      'uv': 0,
#      'short_rad': 0,
#      'diff_rad': 0,
#      'dni': 0,
#      'gti': 0},
#     {'time_epoch': 1767258000,
#      'time': '2026-01-01 04:00',
#      'temp_c': 0.8,
#      'temp_f': 33.4,
#      'is_day': 0,
#      'condition': {'text': 'Overcast ',
#       'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#       'code': 1009},
#      'wind_mph': 6.3,
#      'wind_kph': 10.1,
#      'wind_degree': 278,
#      'wind_dir': 'W',
#      'pressure_mb': 1016.0,
#      'pressure_in': 29.99,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'snow_cm': 0.0,
#      'humidity': 88,
#      'cloud': 100,
#      'feelslike_c': -2.8,
#      'feelslike_f': 27.0,
#      'windchill_c': -2.8,
#      'windchill_f': 27.0,
#      'heatindex_c': 0.8,
#      'heatindex_f': 33.4,
#      'dewpoint_c': -1.0,
#      'dewpoint_f': 30.2,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 8.8,
#      'gust_kph': 14.1,
#      'uv': 0,
#      'short_rad': 0,
#      'diff_rad': 0,
#      'dni': 0,
#      'gti': 0},
#     {'time_epoch': 1767261600,
#      'time': '2026-01-01 05:00',
#      'temp_c': 0.7,
#      'temp_f': 33.2,
#      'is_day': 0,
#      'condition': {'text': 'Overcast ',
#       'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#       'code': 1009},
#      'wind_mph': 5.4,
#      'wind_kph': 8.6,
#      'wind_degree': 307,
#      'wind_dir': 'NW',
#      'pressure_mb': 1016.0,
#      'pressure_in': 30.0,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'snow_cm': 0.0,
#      'humidity': 89,
#      'cloud': 100,
#      'feelslike_c': -2.6,
#      'feelslike_f': 27.4,
#      'windchill_c': -2.6,
#      'windchill_f': 27.4,
#      'heatindex_c': 0.7,
#      'heatindex_f': 33.2,
#      'dewpoint_c': -1.0,
#      'dewpoint_f': 30.3,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 7.3,
#      'gust_kph': 11.8,
#      'uv': 0,
#      'short_rad': 0,
#      'diff_rad': 0,
#      'dni': 0,
#      'gti': 0},
#     {'time_epoch': 1767265200,
#      'time': '2026-01-01 06:00',
#      'temp_c': 0.6,
#      'temp_f': 33.1,
#      'is_day': 0,
#      'condition': {'text': 'Overcast ',
#       'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#       'code': 1009},
#      'wind_mph': 6.7,
#      'wind_kph': 10.8,
#      'wind_degree': 2,
#      'wind_dir': 'N',
#      'pressure_mb': 1017.0,
#      'pressure_in': 30.02,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'snow_cm': 0.0,
#      'humidity': 90,
#      'cloud': 92,
#      'feelslike_c': -2.4,
#      'feelslike_f': 27.7,
#      'windchill_c': -2.4,
#      'windchill_f': 27.7,
#      'heatindex_c': 0.6,
#      'heatindex_f': 33.1,
#      'dewpoint_c': -0.9,
#      'dewpoint_f': 30.4,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 8.8,
#      'gust_kph': 14.2,
#      'uv': 0,
#      'short_rad': 0,
#      'diff_rad': 0,
#      'dni': 0,
#      'gti': 0},
#     {'time_epoch': 1767268800,
#      'time': '2026-01-01 07:00',
#      'temp_c': 0.6,
#      'temp_f': 33.0,
#      'is_day': 0,
#      'condition': {'text': 'Overcast ',
#       'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#       'code': 1009},
#      'wind_mph': 6.5,
#      'wind_kph': 10.4,
#      'wind_degree': 16,
#      'wind_dir': 'NNE',
#      'pressure_mb': 1017.0,
#      'pressure_in': 30.04,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'snow_cm': 0.0,
#      'humidity': 90,
#      'cloud': 88,
#      'feelslike_c': -2.2,
#      'feelslike_f': 28.1,
#      'windchill_c': -2.2,
#      'windchill_f': 28.1,
#      'heatindex_c': 0.6,
#      'heatindex_f': 33.0,
#      'dewpoint_c': -0.9,
#      'dewpoint_f': 30.5,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 8.2,
#      'gust_kph': 13.2,
#      'uv': 0,
#      'short_rad': 0,
#      'diff_rad': 0,
#      'dni': 0,
#      'gti': 0},
#     {'time_epoch': 1767272400,
#      'time': '2026-01-01 08:00',
#      'temp_c': 0.5,
#      'temp_f': 32.9,
#      'is_day': 0,
#      'condition': {'text': 'Cloudy ',
#       'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png',
#       'code': 1006},
#      'wind_mph': 5.4,
#      'wind_kph': 8.6,
#      'wind_degree': 351,
#      'wind_dir': 'N',
#      'pressure_mb': 1018.0,
#      'pressure_in': 30.05,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'snow_cm': 0.0,
#      'humidity': 91,
#      'cloud': 85,
#      'feelslike_c': -1.9,
#      'feelslike_f': 28.6,
#      'windchill_c': -1.9,
#      'windchill_f': 28.6,
#      'heatindex_c': 0.5,
#      'heatindex_f': 32.9,
#      'dewpoint_c': -0.8,
#      'dewpoint_f': 30.5,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 7.1,
#      'gust_kph': 11.5,
#      'uv': 0,
#      'short_rad': 0,
#      'diff_rad': 0,
#      'dni': 0,
#      'gti': 0},
#     {'time_epoch': 1767276000,
#      'time': '2026-01-01 09:00',
#      'temp_c': 0.4,
#      'temp_f': 32.7,
#      'is_day': 1,
#      'condition': {'text': 'Cloudy ',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#       'code': 1006},
#      'wind_mph': 5.4,
#      'wind_kph': 8.6,
#      'wind_degree': 351,
#      'wind_dir': 'N',
#      'pressure_mb': 1019.0,
#      'pressure_in': 30.08,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'snow_cm': 0.0,
#      'humidity': 91,
#      'cloud': 92,
#      'feelslike_c': -1.7,
#      'feelslike_f': 29.0,
#      'windchill_c': -1.7,
#      'windchill_f': 29.0,
#      'heatindex_c': 0.4,
#      'heatindex_f': 32.7,
#      'dewpoint_c': -1.0,
#      'dewpoint_f': 30.3,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 7.4,
#      'gust_kph': 11.9,
#      'uv': 0.2,
#      'short_rad': 20.38,
#      'diff_rad': 8.69,
#      'dni': 26.29,
#      'gti': 3.58},
#     {'time_epoch': 1767279600,
#      'time': '2026-01-01 10:00',
#      'temp_c': 0.4,
#      'temp_f': 32.6,
#      'is_day': 1,
#      'condition': {'text': 'Cloudy ',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#       'code': 1006},
#      'wind_mph': 4.0,
#      'wind_kph': 6.5,
#      'wind_degree': 19,
#      'wind_dir': 'NNE',
#      'pressure_mb': 1019.0,
#      'pressure_in': 30.09,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'snow_cm': 0.0,
#      'humidity': 90,
#      'cloud': 96,
#      'feelslike_c': -1.5,
#      'feelslike_f': 29.3,
#      'windchill_c': -1.5,
#      'windchill_f': 29.3,
#      'heatindex_c': 0.4,
#      'heatindex_f': 32.6,
#      'dewpoint_c': -1.0,
#      'dewpoint_f': 30.1,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 5.0,
#      'gust_kph': 8.0,
#      'uv': 0.8,
#      'short_rad': 76.6,
#      'diff_rad': 24.14,
#      'dni': 144.73,
#      'gti': 0.0},
#     {'time_epoch': 1767283200,
#      'time': '2026-01-01 11:00',
#      'temp_c': 0.6,
#      'temp_f': 33.1,
#      'is_day': 1,
#      'condition': {'text': 'Overcast ',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#       'code': 1009},
#      'wind_mph': 3.8,
#      'wind_kph': 6.1,
#      'wind_degree': 18,
#      'wind_dir': 'NNE',
#      'pressure_mb': 1020.0,
#      'pressure_in': 30.11,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'snow_cm': 0.0,
#      'humidity': 90,
#      'cloud': 100,
#      'feelslike_c': -0.9,
#      'feelslike_f': 30.3,
#      'windchill_c': -0.9,
#      'windchill_f': 30.3,
#      'heatindex_c': 0.6,
#      'heatindex_f': 33.1,
#      'dewpoint_c': -1.1,
#      'dewpoint_f': 30.0,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 4.4,
#      'gust_kph': 7.1,
#      'uv': 1.4,
#      'short_rad': 140.1,
#      'diff_rad': 36.85,
#      'dni': 431.7,
#      'gti': 0.0},
#     {'time_epoch': 1767286800,
#      'time': '2026-01-01 12:00',
#      'temp_c': 0.9,
#      'temp_f': 33.6,
#      'is_day': 1,
#      'condition': {'text': 'Overcast ',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#       'code': 1009},
#      'wind_mph': 3.1,
#      'wind_kph': 5.0,
#      'wind_degree': 8,
#      'wind_dir': 'N',
#      'pressure_mb': 1019.0,
#      'pressure_in': 30.09,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'snow_cm': 0.0,
#      'humidity': 86,
#      'cloud': 91,
#      'feelslike_c': -0.4,
#      'feelslike_f': 31.2,
#      'windchill_c': -0.4,
#      'windchill_f': 31.2,
#      'heatindex_c': 0.9,
#      'heatindex_f': 33.6,
#      'dewpoint_c': -1.2,
#      'dewpoint_f': 29.9,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 3.6,
#      'gust_kph': 5.8,
#      'uv': 2.0,
#      'short_rad': 198.18,
#      'diff_rad': 46.43,
#      'dni': 1825.95,
#      'gti': 0.0},
#     {'time_epoch': 1767290400,
#      'time': '2026-01-01 13:00',
#      'temp_c': 1.1,
#      'temp_f': 34.0,
#      'is_day': 1,
#      'condition': {'text': 'Overcast ',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#       'code': 1009},
#      'wind_mph': 1.6,
#      'wind_kph': 2.5,
#      'wind_degree': 327,
#      'wind_dir': 'NNW',
#      'pressure_mb': 1019.0,
#      'pressure_in': 30.09,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'snow_cm': 0.0,
#      'humidity': 84,
#      'cloud': 86,
#      'feelslike_c': 0.0,
#      'feelslike_f': 32.1,
#      'windchill_c': 0.0,
#      'windchill_f': 32.1,
#      'heatindex_c': 1.1,
#      'heatindex_f': 34.0,
#      'dewpoint_c': -1.2,
#      'dewpoint_f': 29.8,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 1.8,
#      'gust_kph': 2.9,
#      'uv': 2.1,
#      'short_rad': 244.44,
#      'diff_rad': 53.43,
#      'dni': 0.0,
#      'gti': 52.94},
#     {'time_epoch': 1767294000,
#      'time': '2026-01-01 14:00',
#      'temp_c': 1.6,
#      'temp_f': 34.8,
#      'is_day': 1,
#      'condition': {'text': 'Cloudy ',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#       'code': 1006},
#      'wind_mph': 2.7,
#      'wind_kph': 4.3,
#      'wind_degree': 295,
#      'wind_dir': 'WNW',
#      'pressure_mb': 1019.0,
#      'pressure_in': 30.08,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'snow_cm': 0.0,
#      'humidity': 82,
#      'cloud': 82,
#      'feelslike_c': 0.4,
#      'feelslike_f': 32.7,
#      'windchill_c': 0.4,
#      'windchill_f': 32.7,
#      'heatindex_c': 1.6,
#      'heatindex_f': 34.8,
#      'dewpoint_c': -1.3,
#      'dewpoint_f': 29.7,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 3.1,
#      'gust_kph': 5.0,
#      'uv': 1.7,
#      'short_rad': 461.32,
#      'diff_rad': 86.91,
#      'dni': 0.0,
#      'gti': 87.49},
#     {'time_epoch': 1767297600,
#      'time': '2026-01-01 15:00',
#      'temp_c': 1.9,
#      'temp_f': 35.5,
#      'is_day': 1,
#      'condition': {'text': 'Cloudy ',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#       'code': 1006},
#      'wind_mph': 2.9,
#      'wind_kph': 4.7,
#      'wind_degree': 281,
#      'wind_dir': 'WNW',
#      'pressure_mb': 1018.0,
#      'pressure_in': 30.07,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'snow_cm': 0.0,
#      'humidity': 78,
#      'cloud': 75,
#      'feelslike_c': 0.6,
#      'feelslike_f': 33.1,
#      'windchill_c': 0.6,
#      'windchill_f': 33.1,
#      'heatindex_c': 1.9,
#      'heatindex_f': 35.5,
#      'dewpoint_c': -1.4,
#      'dewpoint_f': 29.6,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 3.4,
#      'gust_kph': 5.4,
#      'uv': 1.1,
#      'short_rad': 425.72,
#      'diff_rad': 83.74,
#      'dni': 0.0,
#      'gti': 83.89},
#     {'time_epoch': 1767301200,
#      'time': '2026-01-01 16:00',
#      'temp_c': 2.3,
#      'temp_f': 36.1,
#      'is_day': 1,
#      'condition': {'text': 'Cloudy ',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#       'code': 1006},
#      'wind_mph': 2.9,
#      'wind_kph': 4.7,
#      'wind_degree': 265,
#      'wind_dir': 'W',
#      'pressure_mb': 1018.0,
#      'pressure_in': 30.06,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'snow_cm': 0.0,
#      'humidity': 77,
#      'cloud': 71,
#      'feelslike_c': 0.8,
#      'feelslike_f': 33.4,
#      'windchill_c': 0.8,
#      'windchill_f': 33.4,
#      'heatindex_c': 2.3,
#      'heatindex_f': 36.1,
#      'dewpoint_c': -1.4,
#      'dewpoint_f': 29.5,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 3.4,
#      'gust_kph': 5.4,
#      'uv': 0.5,
#      'short_rad': 373.68,
#      'diff_rad': 78.18,
#      'dni': 0.0,
#      'gti': 77.81},
#     {'time_epoch': 1767304800,
#      'time': '2026-01-01 17:00',
#      'temp_c': 2.2,
#      'temp_f': 36.0,
#      'is_day': 1,
#      'condition': {'text': 'Cloudy ',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#       'code': 1006},
#      'wind_mph': 3.1,
#      'wind_kph': 5.0,
#      'wind_degree': 269,
#      'wind_dir': 'W',
#      'pressure_mb': 1018.0,
#      'pressure_in': 30.05,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'snow_cm': 0.0,
#      'humidity': 75,
#      'cloud': 68,
#      'feelslike_c': 1.1,
#      'feelslike_f': 33.9,
#      'windchill_c': 1.1,
#      'windchill_f': 33.9,
#      'heatindex_c': 2.2,
#      'heatindex_f': 36.0,
#      'dewpoint_c': -1.4,
#      'dewpoint_f': 29.4,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 3.8,
#      'gust_kph': 6.2,
#      'uv': 0.0,
#      'short_rad': 310.1,
#      'diff_rad': 68.8,
#      'dni': 0.0,
#      'gti': 68.07},
#     {'time_epoch': 1767308400,
#      'time': '2026-01-01 18:00',
#      'temp_c': 2.1,
#      'temp_f': 35.8,
#      'is_day': 0,
#      'condition': {'text': 'Cloudy ',
#       'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png',
#       'code': 1006},
#      'wind_mph': 2.2,
#      'wind_kph': 3.6,
#      'wind_degree': 268,
#      'wind_dir': 'W',
#      'pressure_mb': 1018.0,
#      'pressure_in': 30.06,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'snow_cm': 0.0,
#      'humidity': 77,
#      'cloud': 76,
#      'feelslike_c': 1.3,
#      'feelslike_f': 34.4,
#      'windchill_c': 1.3,
#      'windchill_f': 34.4,
#      'heatindex_c': 2.1,
#      'heatindex_f': 35.8,
#      'dewpoint_c': -1.3,
#      'dewpoint_f': 29.6,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 3.3,
#      'gust_kph': 5.3,
#      'uv': 0,
#      'short_rad': 0,
#      'diff_rad': 0,
#      'dni': 0,
#      'gti': 0},
#     {'time_epoch': 1767312000,
#      'time': '2026-01-01 19:00',
#      'temp_c': 2.0,
#      'temp_f': 35.5,
#      'is_day': 0,
#      'condition': {'text': 'Cloudy ',
#       'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png',
#       'code': 1006},
#      'wind_mph': 1.1,
#      'wind_kph': 1.8,
#      'wind_degree': 336,
#      'wind_dir': 'NNW',
#      'pressure_mb': 1018.0,
#      'pressure_in': 30.06,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'snow_cm': 0.0,
#      'humidity': 79,
#      'cloud': 81,
#      'feelslike_c': 1.6,
#      'feelslike_f': 34.8,
#      'windchill_c': 1.6,
#      'windchill_f': 34.8,
#      'heatindex_c': 2.0,
#      'heatindex_f': 35.5,
#      'dewpoint_c': -1.3,
#      'dewpoint_f': 29.7,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 1.9,
#      'gust_kph': 3.0,
#      'uv': 0,
#      'short_rad': 0,
#      'diff_rad': 0,
#      'dni': 0,
#      'gti': 0},
#     {'time_epoch': 1767315600,
#      'time': '2026-01-01 20:00',
#      'temp_c': 2.0,
#      'temp_f': 35.5,
#      'is_day': 0,
#      'condition': {'text': 'Cloudy ',
#       'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png',
#       'code': 1006},
#      'wind_mph': 2.2,
#      'wind_kph': 3.6,
#      'wind_degree': 24,
#      'wind_dir': 'NNE',
#      'pressure_mb': 1018.0,
#      'pressure_in': 30.07,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'snow_cm': 0.0,
#      'humidity': 80,
#      'cloud': 85,
#      'feelslike_c': 1.8,
#      'feelslike_f': 35.2,
#      'windchill_c': 1.8,
#      'windchill_f': 35.2,
#      'heatindex_c': 2.0,
#      'heatindex_f': 35.5,
#      'dewpoint_c': -1.3,
#      'dewpoint_f': 29.7,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 3.8,
#      'gust_kph': 6.0,
#      'uv': 0,
#      'short_rad': 0,
#      'diff_rad': 0,
#      'dni': 0,
#      'gti': 0},
#     {'time_epoch': 1767319200,
#      'time': '2026-01-01 21:00',
#      'temp_c': 2.0,
#      'temp_f': 35.6,
#      'is_day': 0,
#      'condition': {'text': 'Cloudy ',
#       'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png',
#       'code': 1006},
#      'wind_mph': 2.2,
#      'wind_kph': 3.6,
#      'wind_degree': 38,
#      'wind_dir': 'NE',
#      'pressure_mb': 1018.0,
#      'pressure_in': 30.07,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'snow_cm': 0.0,
#      'humidity': 80,
#      'cloud': 91,
#      'feelslike_c': 1.9,
#      'feelslike_f': 35.4,
#      'windchill_c': 1.9,
#      'windchill_f': 35.4,
#      'heatindex_c': 2.0,
#      'heatindex_f': 35.6,
#      'dewpoint_c': -1.0,
#      'dewpoint_f': 30.1,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 3.8,
#      'gust_kph': 6.1,
#      'uv': 0,
#      'short_rad': 0,
#      'diff_rad': 0,
#      'dni': 0,
#      'gti': 0},
#     {'time_epoch': 1767322800,
#      'time': '2026-01-01 22:00',
#      'temp_c': 1.9,
#      'temp_f': 35.4,
#      'is_day': 0,
#      'condition': {'text': 'Cloudy ',
#       'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png',
#       'code': 1006},
#      'wind_mph': 2.2,
#      'wind_kph': 3.6,
#      'wind_degree': 48,
#      'wind_dir': 'NE',
#      'pressure_mb': 1018.0,
#      'pressure_in': 30.07,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'snow_cm': 0.0,
#      'humidity': 81,
#      'cloud': 94,
#      'feelslike_c': -0.4,
#      'feelslike_f': 31.2,
#      'windchill_c': -0.4,
#      'windchill_f': 31.2,
#      'heatindex_c': 1.9,
#      'heatindex_f': 35.4,
#      'dewpoint_c': -0.9,
# ...
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 5.1,
#      'gust_kph': 8.2,
#      'uv': 0,
#      'short_rad': 0,
#      'diff_rad': 0,
#      'dni': 0,
#      'gti': 0},
#     {'time_epoch': 1767358800,
#      'time': '2026-01-02 08:00',
#      'temp_c': 1.6,
#      'temp_f': 34.8,
#      'is_day': 0,
#      'condition': {'text': 'Cloudy ',
#       'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png',
#       'code': 1006},
#      'wind_mph': 2.2,
#      'wind_kph': 3.6,
#      'wind_degree': 40,
#      'wind_dir': 'NE',
#      'pressure_mb': 1016.0,
#      'pressure_in': 30.0,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'snow_cm': 0.0,
#      'humidity': 89,
#      'cloud': 74,
#      'feelslike_c': -0.1,
#      'feelslike_f': 31.8,
#      'windchill_c': -0.1,
#      'windchill_f': 31.8,
#      'heatindex_c': 1.6,
#      'heatindex_f': 34.8,
#      'dewpoint_c': -0.3,
#      'dewpoint_f': 31.6,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 3.7,
#      'gust_kph': 6.0,
#      'uv': 0,
#      'short_rad': 0,
#      'diff_rad': 0,
#      'dni': 0,
#      'gti': 0},
#     {'time_epoch': 1767362400,
#      'time': '2026-01-02 09:00',
#      'temp_c': 1.8,
#      'temp_f': 35.3,
#      'is_day': 1,
#      'condition': {'text': 'Cloudy ',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#       'code': 1006},
#      'wind_mph': 3.4,
#      'wind_kph': 5.4,
#      'wind_degree': 19,
#      'wind_dir': 'NNE',
#      'pressure_mb': 1015.0,
#      'pressure_in': 29.97,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'snow_cm': 0.0,
#      'humidity': 88,
#      'cloud': 87,
#      'feelslike_c': 0.7,
#      'feelslike_f': 33.2,
#      'windchill_c': 0.7,
#      'windchill_f': 33.2,
#      'heatindex_c': 1.8,
#      'heatindex_f': 35.3,
#      'dewpoint_c': -0.0,
#      'dewpoint_f': 32.0,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 5.6,
#      'gust_kph': 9.0,
#      'uv': 0.2,
#      'short_rad': 14.8,
#      'diff_rad': 7.14,
#      'dni': 17.15,
#      'gti': 3.71},
#     {'time_epoch': 1767366000,
#      'time': '2026-01-02 10:00',
#      'temp_c': 2.1,
#      'temp_f': 35.7,
#      'is_day': 1,
#      'condition': {'text': 'Cloudy ',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#       'code': 1006},
#      'wind_mph': 4.0,
#      'wind_kph': 6.5,
#      'wind_degree': 24,
#      'wind_dir': 'NNE',
#      'pressure_mb': 1014.0,
#      'pressure_in': 29.95,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'snow_cm': 0.0,
#      'humidity': 87,
#      'cloud': 94,
#      'feelslike_c': 1.5,
#      'feelslike_f': 34.7,
#      'windchill_c': 1.5,
#      'windchill_f': 34.7,
#      'heatindex_c': 2.1,
#      'heatindex_f': 35.7,
#      'dewpoint_c': 0.1,
#      'dewpoint_f': 32.2,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 6.0,
#      'gust_kph': 9.6,
#      'uv': 0.6,
#      'short_rad': 46.66,
#      'diff_rad': 23.5,
#      'dni': 63.51,
#      'gti': 9.4},
#     {'time_epoch': 1767369600,
#      'time': '2026-01-02 11:00',
#      'temp_c': 2.4,
#      'temp_f': 36.4,
#      'is_day': 1,
#      'condition': {'text': 'Overcast ',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#       'code': 1009},
#      'wind_mph': 5.4,
#      'wind_kph': 8.6,
#      'wind_degree': 25,
#      'wind_dir': 'NNE',
#      'pressure_mb': 1014.0,
#      'pressure_in': 29.94,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'snow_cm': 0.0,
#      'humidity': 86,
#      'cloud': 100,
#      'feelslike_c': 1.6,
#      'feelslike_f': 34.9,
#      'windchill_c': 1.6,
#      'windchill_f': 34.9,
#      'heatindex_c': 2.4,
#      'heatindex_f': 36.4,
#      'dewpoint_c': 0.2,
#      'dewpoint_f': 32.4,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 6.9,
#      'gust_kph': 11.1,
#      'uv': 1.2,
#      'short_rad': 95.24,
#      'diff_rad': 47.06,
#      'dni': 199.53,
#      'gti': 0.0},
#     {'time_epoch': 1767373200,
#      'time': '2026-01-02 12:00',
#      'temp_c': 2.7,
#      'temp_f': 36.9,
#      'is_day': 1,
#      'condition': {'text': 'Overcast ',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#       'code': 1009},
#      'wind_mph': 4.5,
#      'wind_kph': 7.2,
#      'wind_degree': 19,
#      'wind_dir': 'NNE',
#      'pressure_mb': 1013.0,
#      'pressure_in': 29.92,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'snow_cm': 0.0,
#      'humidity': 82,
#      'cloud': 100,
#      'feelslike_c': 1.6,
#      'feelslike_f': 34.8,
#      'windchill_c': 1.6,
#      'windchill_f': 34.8,
#      'heatindex_c': 2.7,
#      'heatindex_f': 36.9,
#      'dewpoint_c': 0.1,
#      'dewpoint_f': 32.1,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 5.4,
#      'gust_kph': 8.6,
#      'uv': 1.5,
#      'short_rad': 134.26,
#      'diff_rad': 66.9,
#      'dni': 787.61,
#      'gti': 0.0},
#     {'time_epoch': 1767376800,
#      'time': '2026-01-02 13:00',
#      'temp_c': 3.0,
#      'temp_f': 37.4,
#      'is_day': 1,
#      'condition': {'text': 'Overcast ',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#       'code': 1009},
#      'wind_mph': 3.8,
#      'wind_kph': 6.1,
#      'wind_degree': 11,
#      'wind_dir': 'NNE',
#      'pressure_mb': 1013.0,
#      'pressure_in': 29.92,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'snow_cm': 0.0,
#      'humidity': 80,
#      'cloud': 100,
#      'feelslike_c': 1.4,
#      'feelslike_f': 34.6,
#      'windchill_c': 1.4,
#      'windchill_f': 34.6,
#      'heatindex_c': 3.0,
#      'heatindex_f': 37.4,
#      'dewpoint_c': 0.0,
#      'dewpoint_f': 32.0,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 4.4,
#      'gust_kph': 7.1,
#      'uv': 1.8,
#      'short_rad': 167.16,
#      'diff_rad': 83.3,
#      'dni': 0.0,
#      'gti': 77.94},
#     {'time_epoch': 1767380400,
#      'time': '2026-01-02 14:00',
#      'temp_c': 3.3,
#      'temp_f': 38.0,
#      'is_day': 1,
#      'condition': {'text': 'Overcast ',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#       'code': 1009},
#      'wind_mph': 5.4,
#      'wind_kph': 8.6,
#      'wind_degree': 9,
#      'wind_dir': 'N',
#      'pressure_mb': 1013.0,
#      'pressure_in': 29.91,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'snow_cm': 0.0,
#      'humidity': 79,
#      'cloud': 100,
#      'feelslike_c': 1.4,
#      'feelslike_f': 34.6,
#      'windchill_c': 1.4,
#      'windchill_f': 34.6,
#      'heatindex_c': 3.3,
#      'heatindex_f': 38.0,
#      'dewpoint_c': -0.0,
#      'dewpoint_f': 31.9,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 6.2,
#      'gust_kph': 9.9,
#      'uv': 1.3,
#      'short_rad': 340.86,
#      'diff_rad': 166.19,
#      'dni': 0.0,
#      'gti': 155.67},
#     {'time_epoch': 1767384000,
#      'time': '2026-01-02 15:00',
#      'temp_c': 3.5,
#      'temp_f': 38.4,
#      'is_day': 1,
#      'condition': {'text': 'Overcast ',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#       'code': 1009},
#      'wind_mph': 5.1,
#      'wind_kph': 8.3,
#      'wind_degree': 4,
#      'wind_dir': 'N',
#      'pressure_mb': 1013.0,
#      'pressure_in': 29.91,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'snow_cm': 0.0,
#      'humidity': 77,
#      'cloud': 94,
#      'feelslike_c': 1.5,
#      'feelslike_f': 34.7,
#      'windchill_c': 1.5,
#      'windchill_f': 34.7,
#      'heatindex_c': 3.5,
#      'heatindex_f': 38.4,
#      'dewpoint_c': 0.0,
#      'dewpoint_f': 32.1,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 6.0,
#      'gust_kph': 9.6,
#      'uv': 0.9,
#      'short_rad': 293.56,
#      'diff_rad': 145.1,
#      'dni': 0.0,
#      'gti': 135.83},
#     {'time_epoch': 1767387600,
#      'time': '2026-01-02 16:00',
#      'temp_c': 3.7,
#      'temp_f': 38.7,
#      'is_day': 1,
#      'condition': {'text': 'Overcast ',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#       'code': 1009},
#      'wind_mph': 6.0,
#      'wind_kph': 9.7,
#      'wind_degree': 1,
#      'wind_dir': 'N',
#      'pressure_mb': 1013.0,
#      'pressure_in': 29.91,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'snow_cm': 0.0,
#      'humidity': 77,
#      'cloud': 91,
#      'feelslike_c': 1.6,
#      'feelslike_f': 34.9,
#      'windchill_c': 1.6,
#      'windchill_f': 34.9,
#      'heatindex_c': 3.7,
#      'heatindex_f': 38.7,
#      'dewpoint_c': 0.1,
#      'dewpoint_f': 32.1,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 7.2,
#      'gust_kph': 11.7,
#      'uv': 0.4,
#      'short_rad': 252.86,
#      'diff_rad': 125.34,
#      'dni': 0.0,
#      'gti': 117.31},
#     {'time_epoch': 1767391200,
#      'time': '2026-01-02 17:00',
#      'temp_c': 3.4,
#      'temp_f': 38.0,
#      'is_day': 1,
#      'condition': {'text': 'Overcast ',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#       'code': 1009},
#      'wind_mph': 6.7,
#      'wind_kph': 10.8,
#      'wind_degree': 358,
#      'wind_dir': 'N',
#      'pressure_mb': 1013.0,
#      'pressure_in': 29.9,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'snow_cm': 0.0,
#      'humidity': 76,
#      'cloud': 89,
#      'feelslike_c': 1.1,
#      'feelslike_f': 34.0,
#      'windchill_c': 1.1,
#      'windchill_f': 34.0,
#      'heatindex_c': 3.4,
#      'heatindex_f': 38.0,
#      'dewpoint_c': 0.1,
#      'dewpoint_f': 32.2,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 8.4,
#      'gust_kph': 13.5,
#      'uv': 0.0,
#      'short_rad': 210.14,
#      'diff_rad': 104.26,
#      'dni': 0.0,
#      'gti': 97.58},
#     {'time_epoch': 1767394800,
#      'time': '2026-01-02 18:00',
#      'temp_c': 3.0,
#      'temp_f': 37.3,
#      'is_day': 0,
#      'condition': {'text': 'Overcast ',
#       'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#       'code': 1009},
#      'wind_mph': 6.5,
#      'wind_kph': 10.4,
#      'wind_degree': 358,
#      'wind_dir': 'N',
#      'pressure_mb': 1013.0,
#      'pressure_in': 29.93,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'snow_cm': 0.0,
#      'humidity': 78,
#      'cloud': 94,
#      'feelslike_c': 0.6,
#      'feelslike_f': 33.1,
#      'windchill_c': 0.6,
#      'windchill_f': 33.1,
#      'heatindex_c': 3.0,
#      'heatindex_f': 37.3,
#      'dewpoint_c': -0.4,
#      'dewpoint_f': 31.3,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 8.9,
#      'gust_kph': 14.3,
#      'uv': 0,
#      'short_rad': 0,
#      'diff_rad': 0,
#      'dni': 0,
#      'gti': 0},
#     {'time_epoch': 1767398400,
#      'time': '2026-01-02 19:00',
#      'temp_c': 2.5,
#      'temp_f': 36.5,
#      'is_day': 0,
#      'condition': {'text': 'Overcast ',
#       'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#       'code': 1009},
#      'wind_mph': 6.5,
#      'wind_kph': 10.4,
#      'wind_degree': 3,
#      'wind_dir': 'N',
#      'pressure_mb': 1014.0,
#      'pressure_in': 29.94,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'snow_cm': 0.0,
#      'humidity': 79,
#      'cloud': 97,
#      'feelslike_c': 0.1,
#      'feelslike_f': 32.1,
#      'windchill_c': 0.1,
#      'windchill_f': 32.1,
#      'heatindex_c': 2.5,
#      'heatindex_f': 36.5,
#      'dewpoint_c': -0.6,
#      'dewpoint_f': 30.9,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 10.0,
#      'gust_kph': 16.1,
#      'uv': 0,
#      'short_rad': 0,
#      'diff_rad': 0,
#      'dni': 0,
#      'gti': 0},
#     {'time_epoch': 1767402000,
#      'time': '2026-01-02 20:00',
#      'temp_c': 1.3,
#      'temp_f': 34.4,
#      'is_day': 0,
#      'condition': {'text': 'Overcast ',
#       'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#       'code': 1009},
#      'wind_mph': 6.9,
#      'wind_kph': 11.2,
#      'wind_degree': 10,
#      'wind_dir': 'N',
#      'pressure_mb': 1014.0,
#      'pressure_in': 29.95,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'snow_cm': 0.0,
#      'humidity': 81,
#      'cloud': 100,
#      'feelslike_c': -1.8,
#      'feelslike_f': 28.8,
#      'windchill_c': -1.8,
#      'windchill_f': 28.8,
#      'heatindex_c': 1.3,
#      'heatindex_f': 34.4,
#      'dewpoint_c': -0.9,
#      'dewpoint_f': 30.4,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 10.9,
#      'gust_kph': 17.6,
#      'uv': 0,
#      'short_rad': 0,
#      'diff_rad': 0,
#      'dni': 0,
#      'gti': 0},
#     {'time_epoch': 1767405600,
#      'time': '2026-01-02 21:00',
#      'temp_c': 0.3,
#      'temp_f': 32.6,
#      'is_day': 0,
#      'condition': {'text': 'Clear ',
#       'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#       'code': 1000},
#      'wind_mph': 7.4,
#      'wind_kph': 11.9,
#      'wind_degree': 9,
#      'wind_dir': 'N',
#      'pressure_mb': 1015.0,
#      'pressure_in': 29.97,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'snow_cm': 0.0,
#      'humidity': 57,
#      'cloud': 5,
#      'feelslike_c': -3.2,
#      'feelslike_f': 26.2,
#      'windchill_c': -3.2,
#      'windchill_f': 26.2,
#      'heatindex_c': 0.3,
#      'heatindex_f': 32.6,
#      'dewpoint_c': -7.3,
#      'dewpoint_f': 18.8,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 11.5,
#      'gust_kph': 18.5,
#      'uv': 0,
#      'short_rad': 0,
#      'diff_rad': 0,
#      'dni': 0,
#      'gti': 0},
#     {'time_epoch': 1767409200,
#      'time': '2026-01-02 22:00',
#      'temp_c': 1.2,
#      'temp_f': 34.2,
#      'is_day': 0,
#      'condition': {'text': 'Clear ',
#       'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#       'code': 1000},
#      'wind_mph': 7.6,
#      'wind_kph': 12.2,
#      'wind_degree': 9,
#      'wind_dir': 'N',
#      'pressure_mb': 1016.0,
#      'pressure_in': 29.99,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'snow_cm': 0.0,
#      'humidity': 55,
#      'cloud': 5,
#      'feelslike_c': -0.6,
#      'feelslike_f': 31.0,
#      'windchill_c': -0.6,
#      'windchill_f': 31.0,
#      'heatindex_c': 1.2,
#      'heatindex_f': 34.2,
#      'dewpoint_c': -8.5,
#      'dewpoint_f': 16.6,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 11.6,
#      'gust_kph': 18.6,
#      'uv': 0,
#      'short_rad': 0,
#      'diff_rad': 0,
#      'dni': 0,
#      'gti': 0},
#     {'time_epoch': 1767412800,
#      'time': '2026-01-02 23:00',
#      'temp_c': -0.3,
#      'temp_f': 31.5,
#      'is_day': 0,
#      'condition': {'text': 'Overcast ',
#       'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#       'code': 1009},
#      'wind_mph': 6.9,
#      'wind_kph': 11.2,
#      'wind_degree': 11,
#      'wind_dir': 'NNE',
#      'pressure_mb': 1018.0,
#      'pressure_in': 30.07,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'snow_cm': 0.0,
#      'humidity': 81,
#      'cloud': 97,
#      'feelslike_c': -3.1,
#      'feelslike_f': 26.5,
#      'windchill_c': -3.1,
#      'windchill_f': 26.5,
#      'heatindex_c': -0.3,
#      'heatindex_f': 31.5,
#      'dewpoint_c': -0.8,
#      'dewpoint_f': 30.5,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 10.4,
#      'gust_kph': 16.8,
#      'uv': 0,
#      'short_rad': 0,
#      'diff_rad': 0,
#      'dni': 0,
#      'gti': 0}]}]}

# %%
forecast_3_day_summary = []
for day in forecast:
    forecast_3_day_summary.append(f"{day['date']}: High {day['day']['maxtemp_f']}F, Low: {day['day']['mintemp_f']}F - {day['day']['condition']['text']}")

# %%
forecast_3_day_summary = []
for day in forecast:
        date_obj = datetime.strptime(day['date'], '%Y-%m-%d')
        formatted_date = date_obj.strftime('%A,%B %#d')
        forecast_3_day_summary.append(f"{formatted_date}: High {day['day']['maxtemp_f']}F / Low: {day['day']['mintemp_f']}F - {day['day']['condition']['text']}")

forecast_3_day_summary
# Out:
# ['Wednesday,December #d: High 37.2F / Low: 30.9F - Overcast ',
#  'Thursday,January #d: High 36.7F / Low: 32.5F - Cloudy ',
#  'Friday,January #d: High 39.0F / Low: 30.8F - Overcast ']

# %% [markdown]
# ## Astronomy

# %%
city = "Las Vegas"

today = pd.Timestamp.now().strftime('%Y-%m-%d')
astronomy_url = f"{baseurl}astronomy.json?key={api_key}&q={city}&dt={today}"
    
astronomy_response = requests.get(astronomy_url)
astronomy_response.status_code
# Out:
# 200

# %%
astronomy_response.json()
# Out:
# {'location': {'name': 'Las Vegas',
#   'region': 'Nevada',
#   'country': 'United States of America',
#   'lat': 36.175,
#   'lon': -115.1364,
#   'tz_id': 'America/Los_Angeles',
#   'localtime_epoch': 1767133091,
#   'localtime': '2025-12-30 14:18'},
#  'astronomy': {'astro': {'sunrise': '06:51 AM',
#    'sunset': '04:35 PM',
#    'moonrise': '12:58 PM',
#    'moonset': '02:45 AM',
#    'moon_phase': 'Waxing Gibbous',
#    'moon_illumination': 77,
#    'is_moon_up': 0,
#    'is_sun_up': 1}}}

# %%
astro_data = astronomy_response.json()
astro_data['astronomy']
# Out:
# {'astro': {'sunrise': '06:51 AM',
#   'sunset': '04:35 PM',
#   'moonrise': '12:58 PM',
#   'moonset': '02:45 AM',
#   'moon_phase': 'Waxing Gibbous',
#   'moon_illumination': 77,
#   'is_moon_up': 0,
#   'is_sun_up': 1}}

# %%
astro = astro_data['astronomy']['astro']

astro_info = []

for rise_set in astro:
    astro_info.append(f"Sunrise: {astro['sunrise']}, Sunset: {astro['sunset']}")


astro_info
# Out:
# ['Sunrise: 06:51 AM, Sunset: 04:35 PM',
#  'Sunrise: 06:51 AM, Sunset: 04:35 PM',
#  'Sunrise: 06:51 AM, Sunset: 04:35 PM',
#  'Sunrise: 06:51 AM, Sunset: 04:35 PM',
#  'Sunrise: 06:51 AM, Sunset: 04:35 PM',
#  'Sunrise: 06:51 AM, Sunset: 04:35 PM',
#  'Sunrise: 06:51 AM, Sunset: 04:35 PM',
#  'Sunrise: 06:51 AM, Sunset: 04:35 PM']

# %%
# Removing the loop

astro = astro_data['astronomy']['astro']

astro_info = f"Sunrise: {astro['sunrise']}, Sunset: {astro['sunset']}"

astro_info
# Out:
# 'Sunrise: 06:51 AM, Sunset: 04:35 PM'
